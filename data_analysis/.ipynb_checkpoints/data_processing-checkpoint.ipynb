# %%
import pandas as pd  # Import pandas for data manipulation
from rdkit import Chem  # Import RDKit for chemical informatics
from rdkit.Chem import rdMolDescriptors  # Import molecular descriptor functions from RDKit

# %% [markdown]
# # GABAA_processing

# %%
# Load the 'GABAA.csv' file into a pandas DataFrame
data = pd.read_csv('../data/GABAA.csv', encoding='gb2312')

# %%
# Function to check if a given SMILES string contains metal atoms
def contains_metal(smiles):
    mol = Chem.MolFromSmiles(smiles)  # Convert SMILES string to RDKit molecular object
    if mol:  # Check if molecule conversion was successful
        for atom in mol.GetAtoms():  # Iterate through each atom in the molecule
            # Check if the atomic number corresponds to a metal
            if atom.GetAtomicNum() in [3, 11, 13, 19, 20, 25, 26, 29, 30, 42, 47, 50, 73, 74, 78, 79, 80, 82, 83]:
                return True  # Return True if a metal atom is found
    return False  # Return False if no metal atoms are found

# %%
# Filter out molecules that contain metal atoms
filtered_df = data[~data['smiles'].apply(contains_metal)]

# %%
# Calculate the exact molecular weight for each molecule
filtered_df['molecular_weight'] = filtered_df['smiles'].apply(
    lambda x: rdMolDescriptors.CalcExactMolWt(Chem.MolFromSmiles(x)) if Chem.MolFromSmiles(x) else None
)

# %%
# Further filter molecules based on molecular weight (between 30 and 1000 Da)
filtered_df_2 = filtered_df[(filtered_df['molecular_weight'] >= 30) & (filtered_df['molecular_weight'] <= 1000)]

# %%
filtered_df_2
# Out:
#                         name                         origin             label  \
# 0    gamma-Aminobutyric acid      10.3390/molecules24152678     GABAA agonist
# 1                    Menthol              10.1111/bph.12602     GABAA agonist
# 2              phenobarbital              10.1002/ana.24967     GABAA agonist
# 3          isoguvacine oxide         10.1002/chir.530070608     GABAA agonist
# 4              Clomethiazole  10.1016/s0014-2999(02)02233-1     GABAA agonist
# ..                       ...                            ...               ...
# 483         chlorogenic acid              10.1021/jf0303971  GABAA inhibition
# 484                   maltol              10.1021/jf0303971  GABAA inhibition
# 485              Theobromine              10.1021/jf0303971  GABAA inhibition
# 486  2,3,5-trimethylpyrazine              10.1021/jf0303971  GABAA inhibition
# 487            benzothiazole              10.1021/jf0303971  GABAA inhibition
#
#                                                 smiles  class  \
# 0                                         C(CC(=O)O)CN      1
# 1                                  CC1CCC(C(C1)O)C(C)C      1
# 2                    CCC1(C(=O)NC(=O)NC1=O)C2=CC=CC=C2      1
# 3                                  C1CNCC2C1(O2)C(=O)O      1
# 4                                     CC1=C(CCCl)SC=N1      1
# ..                                                 ...    ...
# 483  C1C(C(C(CC1(C(=O)O)O)OC(=O)C=CC2=CC(=C(C=C2)O)...      0
# 484                                 CC1=C(C(=O)C=CO1)O      0
# 485                          CN1C=NC2=C1C(=O)NC(=O)N2C      0
# 486                        CN1C2=C(C(=O)N(C1=O)C)NC=N2      0
# 487                                 CC1=CN=C(C(=N1)C)C      0
#
#      molecular_weight
# 0          103.063329
# 1          156.151415
# 2          232.084792
# 3          143.058243
# 4          161.006598
# ..                ...
# 483        354.095082
# 484        126.031694
# 485        180.064725
# 486        180.064725
# 487        122.084398
#
# [488 rows x 6 columns]

# %%
# Save the filtered dataset back to 'GABAA.csv'
filtered_df_2.to_csv('GABAA.csv')

# %% [markdown]
# # plant_processing

# %%
# Load the 'plant.xlsx' file into a pandas DataFrame
plant = pd.read_excel('../data/plant.xlsx')

# %%
# Filter out molecules that contain metal atoms in the plant dataset
filtered_plant = plant[~plant['SMILES'].apply(contains_metal)]

# %%
# Calculate the exact molecular weight for each molecule in the plant dataset
filtered_plant['molecular_weight'] = filtered_plant['SMILES'].apply(
    lambda x: rdMolDescriptors.CalcExactMolWt(Chem.MolFromSmiles(x)) if Chem.MolFromSmiles(x) else None
)

# %%
# Further filter plant molecules based on molecular weight (between 30 and 1000 Da)
filtered_plant_2 = filtered_plant[(filtered_plant['molecular_weight'] >= 30) & (filtered_plant['molecular_weight'] <= 1000)]

# %%
filtered_plant_2
# Out:
#             Scientific name Chinese name Extraction site  \
# 0              Lamium album        短柄野芝麻          flower
# 1              Lamium album        短柄野芝麻          flower
# 2              Lamium album        短柄野芝麻          flower
# 3              Lamium album        短柄野芝麻          flower
# 4              Lamium album        短柄野芝麻          flower
# ...                     ...          ...             ...
# 10810  Hyssopus officinalis          神香草            leaf
# 10811  Hyssopus officinalis          神香草            leaf
# 10812  Hyssopus officinalis          神香草            leaf
# 10813  Hyssopus officinalis          神香草            leaf
# 10814  Hyssopus officinalis          神香草            leaf
#
#                       Volatile compounds  Compound content Analysis method  \
# 0      6,10,14-Trimethylpentadecan-2-one            0.1020           GC-MS
# 1                      Diacetone alcohol            0.0910           GC-MS
# 2                             1-Pentanol            0.0410           GC-MS
# 3                            Tetracosane            0.0390           GC-MS
# 4                              Tricosane            0.0370           GC-MS
# ...                                  ...               ...             ...
# 10810                            Myrcene            0.0052           GC-MS
# 10811                   cis-Pinonic acid            0.0063           GC-MS
# 10812                    beta-bisabolene            0.0057           GC-MS
# 10813                             Elemol            0.0055           GC-MS
# 10814                        Spathulenol            0.0059           GC-MS
#
#                                                     Cite  \
# 0      Morteza-Semnani K, Saeedi M, Akbarzadeh M. Che...
# 1      Morteza-Semnani K, Saeedi M, Akbarzadeh M. Che...
# 2      Morteza-Semnani K, Saeedi M, Akbarzadeh M. Che...
# 3      Morteza-Semnani K, Saeedi M, Akbarzadeh M. Che...
# 4      Morteza-Semnani K, Saeedi M, Akbarzadeh M. Che...
# ...                                                  ...
# 10810  KIZIL S, HAŞİMİ N, Tolan V, et al. Chemical co...
# 10811  KIZIL S, HAŞİMİ N, Tolan V, et al. Chemical co...
# 10812  KIZIL S, HAŞİMİ N, Tolan V, et al. Chemical co...
# 10813  KIZIL S, HAŞİMİ N, Tolan V, et al. Chemical co...
# 10814  KIZIL S, HAŞİMİ N, Tolan V, et al. Chemical co...
#
#                     Species     Genus     Family     Order          Class  \
# 0              Lamium album    Lamium  Lamiaceae  Lamiales  Magnoliopsida
# 1              Lamium album    Lamium  Lamiaceae  Lamiales  Magnoliopsida
# 2              Lamium album    Lamium  Lamiaceae  Lamiales  Magnoliopsida
# 3              Lamium album    Lamium  Lamiaceae  Lamiales  Magnoliopsida
# 4              Lamium album    Lamium  Lamiaceae  Lamiales  Magnoliopsida
# ...                     ...       ...        ...       ...            ...
# 10810  Hyssopus officinalis  Hyssopus  Lamiaceae  Lamiales  Magnoliopsida
# 10811  Hyssopus officinalis  Hyssopus  Lamiaceae  Lamiales  Magnoliopsida
# 10812  Hyssopus officinalis  Hyssopus  Lamiaceae  Lamiales  Magnoliopsida
# 10813  Hyssopus officinalis  Hyssopus  Lamiaceae  Lamiales  Magnoliopsida
# 10814  Hyssopus officinalis  Hyssopus  Lamiaceae  Lamiales  Magnoliopsida
#
#              Phylum  Kingdom                           SMILES  \
# 0      Angiospermae  Plantae     CC(C)CCCC(C)CCCC(C)CCCC(=O)C
# 1      Angiospermae  Plantae                  CC(=O)CC(C)(C)O
# 2      Angiospermae  Plantae                           CCCCCO
# 3      Angiospermae  Plantae         CCCCCCCCCCCCCCCCCCCCCCCC
# 4      Angiospermae  Plantae          CCCCCCCCCCCCCCCCCCCCCCC
# ...             ...      ...                              ...
# 10810  Angiospermae  Plantae                CC(=CCCC(=C)C=C)C
# 10811  Angiospermae  Plantae        CC(=O)C1CC(C1(C)C)CC(=O)O
# 10812  Angiospermae  Plantae       CC1=CCC(CC1)C(=C)CCC=C(C)C
# 10813  Angiospermae  Plantae   CC(=C)C1CC(CCC1(C)C=C)C(C)(C)O
# 10814  Angiospermae  Plantae  CC1(C2C1C3C(CCC3(C)O)C(=C)CC2)C
#
#        molecular_weight
# 0            268.276616
# 1            116.083730
# 2             88.088815
# 3            338.391252
# 4            324.375602
# ...                 ...
# 10810        136.125201
# 10811        184.109944
# 10812        204.187801
# 10813        222.198365
# 10814        220.182715
#
# [10815 rows x 16 columns]

# %%
# Save the filtered plant dataset to 'filtered_plant.csv'
filtered_plant_2.to_excel('../data/plant.xlsx')

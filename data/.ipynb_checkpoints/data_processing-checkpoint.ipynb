# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

# %%
data = pd.read_csv('GABAA_data.csv',encoding = 'gb2312')

# %%
data
# Out:
#                                                    name  \
# 0     1-[(3-{6-chloroimidazo[1,2-a]pyridin-2-yl}benz...
# 1     1-[(3-{8-methylimidazo[1,2-a]pyridin-2-yl}benz...
# 2     3-(4-chlorophenyl)-6-(3,4,5-trimethoxyphenyl)-...
# 3     2-[2-(4-chlorophenyl)imidazo[1,2-a]pyridin-3-y...
# 4     2-[10-(5-chloro-2-methylphenyl)-3,4,6,8,10,11-...
# ...                                                 ...
# 1246                                       Tetrodotoxin
# 1247                                        Pentetrazol
# 1248                      Salicylidene Salicylhydrazide
# 1249                                             RU5135
# 1250                                         Bilobalide
#
#                                                  smiles      source  \
# 0        Clc1ccc2nc(cn2c1)-c1cccc(c1)S(=O)(=O)N1CCCCCC1  Topscience
# 1         Cc1cccn2cc(nc12)-c1cccc(c1)S(=O)(=O)N1CCCCCC1  Topscience
# 2        COc1cc(cc(OC)c1OC)-c1nn2c(nnc2s1)-c1ccc(Cl)cc1  Topscience
# 3                   OC(=O)Cc1c(nc2ccccn12)-c1ccc(Cl)cc1  Topscience
# 4          Cc1ccc(Cl)cc1-n1ncc2c1ncn1c(nnc21)-c1ccccc1O  Topscience
# ...                                                 ...         ...
# 1246      C(C1(C2C3C(N=C(NC34C(C1OC(C4O)(O2)O)O)N)O)O)O  Literature
# 1247                                   C1CCC2=NN=NN2CC1  Literature
# 1248            C1=CC=C(C(=C1)/C=N/NC(=O)C2=CC=CC=C2O)O  Literature
# 1249  C[C@]12CC[C@H](C[C@H]1CC[C@@H]3[C@@H]2C(=O)C[C...  Literature
# 1250  CC(C)(C)[C@@]1(C[C@H]2[C@@]3([C@]14[C@H](C(=O)...  Literature
#
#                  class
# 0        GABAA agonist
# 1        GABAA agonist
# 2        GABAA agonist
# 3        GABAA agonist
# 4        GABAA agonist
# ...                ...
# 1246  GABAA antagonist
# 1247  GABAA antagonist
# 1248  GABAA antagonist
# 1249  GABAA antagonist
# 1250  GABAA antagonist
#
# [1251 rows x 4 columns]

# %% [markdown]
# # 标准化

# %%
gabaa_smiles = data['smiles']

# %%
def standardize_smi(smiles,basicClean=True,clearCharge=True, clearFrag=True, canonTautomer=True, isomeric=False):
    try:
         clean_mol = Chem.MolFromSmiles(smiles)
        # 除去氢、金属原子、标准化分子
         if basicClean:
            clean_mol = rdMolStandardize.Cleanup(clean_mol) 
        # 仅保留主要片段作为分子
#          if clearFrag:
#             clean_mol = rdMolStandardize.FragmentParent(clean_mol)
        # 尝试中性化处理分子
         if clearCharge:
            uncharger = rdMolStandardize.Uncharger() 
            clean_mol = uncharger.uncharge(clean_mol)
        # 处理互变异构情形，这一步在某些情况下可能不够完美
         if canonTautomer:
            te = rdMolStandardize.TautomerEnumerator() # idem
            clean_mol = te.Canonicalize(clean_mol)
        #set to True 保存立体信息，set to False 移除立体信息，并将分子存为标准化后的SMILES形式
         stan_smiles=Chem.MolToSmiles(clean_mol, isomericSmiles=isomeric)
    except Exception as e:
        print (e, smiles)
        return None
    return stan_smiles

# %%
stan_smiles_list = []
for smiles in gabaa_smiles:
    stan_smiles = standardize_smi(smiles)
    stan_smiles_list.append(stan_smiles)

# %%
stan_df = pd.DataFrame({'name':data['name'],'smiles':stan_smiles_list,'source':data['source'],'class':data['class']})

# %%
stan_df['class'] = stan_df['class'].replace({'GABAA agonist': 1, 'GABAA antagonist': 0})

# %%
counts = stan_df['class'].value_counts()

print('Number of 1s:', counts[1])
print('Number of 0s:', counts[0])
# Out:
# Number of 1s: 609
# Number of 0s: 642

# %%
stan_df
# Out:
#                                                    name  \
# 0     1-[(3-{6-chloroimidazo[1,2-a]pyridin-2-yl}benz...
# 1     1-[(3-{8-methylimidazo[1,2-a]pyridin-2-yl}benz...
# 2     3-(4-chlorophenyl)-6-(3,4,5-trimethoxyphenyl)-...
# 3     2-[2-(4-chlorophenyl)imidazo[1,2-a]pyridin-3-y...
# 4     2-[10-(5-chloro-2-methylphenyl)-3,4,6,8,10,11-...
# ...                                                 ...
# 1246                                       Tetrodotoxin
# 1247                                        Pentetrazol
# 1248                      Salicylidene Salicylhydrazide
# 1249                                             RU5135
# 1250                                         Bilobalide
#
#                                                 smiles      source  class
# 0       O=S(=O)(c1cccc(-c2cn3cc(Cl)ccc3n2)c1)N1CCCCCC1  Topscience      1
# 1        Cc1cccn2cc(-c3cccc(S(=O)(=O)N4CCCCCC4)c3)nc12  Topscience      1
# 2       COc1cc(-c2nn3c(-c4ccc(Cl)cc4)nnc3s2)cc(OC)c1OC  Topscience      1
# 3                  O=C(O)Cc1c(-c2ccc(Cl)cc2)nc2ccccn12  Topscience      1
# 4         Cc1ccc(Cl)cc1-n1ncc2c1ncn1c(-c3ccccc3O)nnc21  Topscience      1
# ...                                                ...         ...    ...
# 1246       NC1=NC(O)C2C3OC4(O)OC(C(O)C2(N1)C4O)C3(O)CO  Literature      0
# 1247                                    C1CCc2nnnn2CC1  Literature      0
# 1248                       O=C(NN=Cc1ccccc1O)c1ccccc1O  Literature      0
# 1249          CC12CC(=O)C3C(CCC4CC(O)CCC43C)C1CC(=N)N2  Literature      0
# 1250  CC(C)(C)C1(O)CC2OC(=O)CC23C(=O)OC2OC(=O)C(O)C231  Literature      0
#
# [1251 rows x 4 columns]

# %%
stan_df.to_csv('stan_data.csv')

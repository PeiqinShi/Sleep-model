# %%
from rdkit import Chem
from rdkit.Chem import Descriptors
import pandas as pd

# %%
# 定义一个函数来计算分子的分子量、脂水分配系数、可旋转键数、拓扑分子极性表面积、环数、芳香环数、氢键供体数和氢键受体数
def calc_mol_properties(smiles):
    mol = Chem.MolFromSmiles(smiles)
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    rotatable_bonds = Descriptors.NumRotatableBonds(mol)
    tpsa = Descriptors.TPSA(mol)
    Rings = Descriptors.RingCount(mol)
    AroRings = Descriptors.NumAromaticRings(mol)
    h_donors = Descriptors.NumHDonors(mol)
    h_acceptors = Descriptors.NumHAcceptors(mol)
    return mol_weight, logp, rotatable_bonds, tpsa,Rings, AroRings, h_donors, h_acceptors

# %%
smiles_agonist = pd.read_csv('stan_data.csv')[0:609]['stan_smiles'].tolist()

# %%
smiles_agonist
# Out:
# ['O=S(=O)(c1cccc(-c2cn3cc(Cl)ccc3n2)c1)N1CCCCCC1',
#  'Cc1cccn2cc(-c3cccc(S(=O)(=O)N4CCCCCC4)c3)nc12',
#  'COc1cc(-c2nn3c(-c4ccc(Cl)cc4)nnc3s2)cc(OC)c1OC',
#  'O=C(O)Cc1c(-c2ccc(Cl)cc2)nc2ccccn12',
#  'Cc1ccc(Cl)cc1-n1ncc2c1ncn1c(-c3ccccc3O)nnc21',
#  'Cc1[nH]c2ccc(F)cc2c(=O)c1CN1CCc2ccccc2C1',
#  'Cc1c(-c2nc(-c3ccccc3F)no2)nnn1-c1ccc(F)c(Cl)c1',
#  'Cc1ccccc1-n1ncc2c1ncn1c(-c3ccccc3O)nnc21',
#  'Cc1ccc(-c2nnc3c4cnn(-c5ccccc5Cl)c4ncn23)cc1',
#  'N#Cc1nc(-c2ccccc2F)oc1S(=O)(=O)c1ccc(Cl)cc1',
#  'N#Cc1nc(-c2ccccc2)oc1S(=O)(=O)Cc1ccc(Cl)cc1Cl',
#  'Cn1c(=O)c2c(nc3n(-c4cccc(Cl)c4)c(-c4cccc([N+](=O)[O-])c4)cn23)n(C)c1=O',
#  'Cc1ccc(Sc2oc(-c3ccccc3F)nc2C#N)cc1',
#  'Cc1ccc(-n2ncc3c2ncn2c(-c4ccccc4Cl)nnc32)c(C)c1',
#  'Cc1c(-c2nc(-c3ccccc3F)no2)nnn1-c1ccc(Br)cc1',
#  'Oc1cc2ccccc2cc1-c1nnc2c3cnn(-c4ccc(F)cc4)c3ncn12',
#  'Cc1ccc(S(=O)(=O)c2oc(-c3ccccc3F)nc2C#N)cc1',
#  'COc1ccc(-c2nnc3c4cnn(-c5ccc(Cl)cc5)c4ncn23)cc1OC',
#  'CCN1CCN(C(=O)c2cc(-c3ccccc3)nc3c2c(C)nn3C)CC1',
#  'Cc1ccc(-c2nc3c(C)cccn3c2CC(=O)O)cc1C',
#  'CCOC(=O)c1c(N)n(-c2ccc(C)c(Cl)c2)c2nc3ccccc3nc12',
#  'CCOc1ccc(-c2cn3c4c(=O)n(C)c(=O)n(C)c4nc3n2-c2ccc(F)cc2)cc1Cl',
#  'O=C(O)c1cc(-c2ccccc2)[nH]c(=O)n1',
#  'Clc1cccc(-n2ncc3c(N4CCN(Cc5ccccc5)CC4)ncnc32)c1',
#  'CC(C)OCCCNc1ncnc2c1c(-c1ccccc1)cn2-c1ccccc1',
#  'Clc1ccc2nc(CSc3nnnn3-c3ccccc3)c(Br)n2c1',
#  'COc1cccc(-c2cn3c4c(=O)n(C)c(=O)n(C)c4nc3n2-c2ccc(F)cc2)c1',
#  'CCOC(=O)c1csc(NC(=O)c2ccccc2-n2cnnn2)n1',
#  'CCOC(=O)c1sc2ncn(Cc3ccc(Cl)cc3Cl)c(=O)c2c1C',
#  'Cc1ccc2[nH]c(-c3ccccc3)c(CN3CCN(C)CC3)c(=O)c2c1',
#  'Cc1ccn2c(CC(=O)O)c(-c3ccc(C)c(C)c3)nc2c1',
#  'CCN(CC)S(=O)(=O)c1cccc(-c2cn3cc(Cl)ccc3n2)c1',
#  'Cc1ccc(-c2nnc3c4cnn(-c5ccc(C)c(Cl)c5)c4ncn23)cc1',
#  'CCOc1ccc(-c2nc(N)nc(C)c2-c2ccc(Cl)cc2)c(O)c1',
#  'CCOc1ccc(-c2ncncc2-c2ccc(Br)cc2)c(O)c1',
#  'CC1CN(S(=O)(=O)c2cccc(-c3cn4ccccc4n3)c2)CC(C)O1',
#  'O=C1c2[nH]nc(-c3ccccc3O)c2C(c2ccccc2F)N1Cc1ccncc1',
#  'Cc1[nH]c2ccccc2c(=O)c1CN1CCc2ccccc2C1',
#  'Cn1c(=O)c2c(nc3n(-c4ccccc4)c(-c4ccc(O)c(Cl)c4)cn23)n(C)c1=O',
#  'COc1cccc(-c2cn3c4c(=O)n(C)c(=O)n(C)c4nc3n2-c2ccc(Cl)cc2)c1',
#  'Cc1cc(Br)cn2c(CN3CCN(C(=O)OC(C)(C)C)CC3)cnc12',
#  'Cc1ccccc1-c1noc(-c2nnn(-c3cc(F)ccc3F)c2C)n1',
#  'O=C1c2ccccc2C(=O)N1CCc1cn2cc(Cl)cc(Cl)c2n1',
#  'Cc1[nH]c2ccc(Br)cc2c(=O)c1CN1CCc2ccccc2C1',
#  'Cc1cccc2nc(CCN3C(=O)c4ccccc4C3=O)cn12',
#  'Fc1ccc(-c2nnnn2-c2ccc(Br)cn2)cc1',
#  'CCc1cc2c(N3CCN(C(=O)c4ccc(C)cc4)CC3)nc(C)nc2s1',
#  'COC(=O)CSc1nnc(-c2sc3ccccc3c2Cl)n1C',
#  'COc1cc(-n2nnc(C(=O)NCc3ccccc3)c2N)ccc1Cl',
#  'Cc1ccc(C(=O)Nc2nnc(C3CCCO3)s2)c(-n2cnnn2)c1C',
#  'COc1ccc(CN(Cc2ccco2)C(=O)c2cc(=O)c3ccc(Br)cc3o2)cc1',
#  'CN(C)C(CNC(=O)c1cc(-c2ccc3c(c2)CCCC3)on1)c1ccccc1',
#  'COc1ccc(-c2cc(=O)oc3cc(OCC(=O)OCc4ccccc4)ccc23)cc1',
#  'CCOC(=O)c1cnc2ccc(Cl)cc2c1Nc1cc(Cl)ccc1O',
#  'Cc1nc(SCC(=O)Nc2c(F)cccc2F)c2cc(-c3ccccc3)sc2n1',
#  'Cc1cc(C)n(-c2ccc3nnc(CCCC(=O)Nc4cc(F)c(F)c(F)c4)n3n2)n1',
#  'Cc1oc2cc3oc(=O)c(CC(=O)NCCc4ccccc4F)c(C)c3cc2c1C',
#  'O=C(CSc1nnc2ccc3ccccc3n12)c1cc2ccccc2o1',
#  'COc1ccc2cnn(CC(=O)NCCCc3nc4ccccc4[nH]3)c(=O)c2c1OC',
#  'O=C(Cc1cccc2ccccc12)NNc1ncnc2c1cnn2-c1cccc(Cl)c1',
#  'COCCCn1c(C(=O)NCc2ccccc2Cl)cc2c(=O)n3ccccc3nc21',
#  'Cc1ccc(-n2ncc3c(NCCCn4ccnc4)ncnc32)cc1C',
#  'Cc1ccc(CNC(=O)Cc2c(C)c3c(cc(C)c4c(C)coc43)oc2=O)cc1',
#  'Cc1oc2c(C)c3oc(=O)c(CC(=O)NCc4ccco4)c(C)c3cc2c1C',
#  'Cc1oc2cc3oc(=O)c(CC(=O)NCc4ccco4)c(C)c3cc2c1-c1ccccc1',
#  'Fc1ccccc1N1CCN(c2ncnc3c2cnn3-c2cccc(Cl)c2)CC1',
#  'Cc1ccc(C(=O)NCCc2nnc3ccccn23)c(-n2cnnn2)c1C',
#  'Cc1csc(NC(=O)CCc2nnc3ccc(-n4nc(C)cc4C)nn23)n1',
#  'Cc1ccc(C(=O)NCCCc2nc3ccccc3[nH]2)c(-n2cnnn2)c1C',
#  'O=C(CSc1nc2ccccc2c2nnnn12)NCC(=O)Nc1ncns1',
#  'O=C(CSc1nc2ccccc2c2nnnn12)NCc1cccc(Cl)c1',
#  'Cc1ccc(C)c(NC(=O)Cn2nnc(-c3ccc(Cl)cc3)n2)c1',
#  'Cc1c(CCC(=O)Nn2cnnc2)c(=O)oc2cc3occ(-c4ccccc4)c3cc12',
#  'Cc1sc2ncnc(SCC(=O)c3ccc4ccccc4c3)c2c1C',
#  'O=C(NCCc1nc2ccccc2[nH]1)c1cc(Cl)ccc1-n1cnnn1',
#  'Cc1oc2cc3oc(=O)c(CCC(=O)N4CCc5ccccc5C4)c(C)c3cc2c1C',
#  'Cc1oc2c(C)c3oc(=O)c(CCC(=O)NCCc4ccccn4)c(C)c3cc2c1C',
#  'Cc1ccc(-n2nnnc2SCC(=O)Nc2ccc3nccnc3c2)cc1Cl',
#  'COc1ccc(CNC(=O)Cc2c(C)c3c(cc(C)c4c(C)coc43)oc2=O)cc1OC',
#  'COc1ccc(-c2nonc2NC(=O)c2ccc(Cl)cc2Cl)cc1',
#  'O=c1c(O)c(-c2ccc(F)cc2)oc2cc(Cl)ccc12',
#  'COC(=O)c1c(NC(=O)CSc2ncnc3sc(-c4ccccc4)cc23)sc(C)c1C',
#  'Cc1ccc(NC(=O)CSc2nnc3cc(-c4ccccc4)nc(C)n23)cc1',
#  'Cc1cccc(-n2ncc3c(Nc4c(C)n(C)n(-c5ccccc5)c4=O)ncnc32)c1',
#  'COc1ccc(CCNC(=O)c2c(N)n(CCc3ccc(F)cc3)c3nc4ccccc4nc23)cc1',
#  'COc1ccccc1-c1nc2nccc(-c3cc4ccccc4o3)n2n1',
#  'COc1ccc(C(=O)NNc2ncnc3c2cnn3-c2ccc(C)cc2C)cc1',
#  'CCN(CC)CCCNc1ncnc2c1cnn2-c1ccc(F)cc1',
#  'CC1CCc2c(sc3ncn4c(CCc5ccccc5)nnc4c23)C1',
#  'Fc1ccc(-n2ncc3c(SCCOc4ccccc4)ncnc32)cc1',
#  'Cc1ccc(-n2ncc3c(NCCO)nc(N4CCN(c5ccccc5F)CC4)nc32)cc1',
#  'O=c1c2c3nc4ccccc4nc3n(CCc3ccccc3)c2ncn1Cc1ccco1',
#  'COc1ccc(CCNc2ncnc3c2cnn3-c2ccc(F)cc2)cc1OC',
#  'Cc1ccc(-n2ncc3c(N4CCN(Cc5ccccc5)CC4)ncnc32)cc1C',
#  'COc1ccc2c(C)c(CC(=O)Nc3nnc(C)s3)c(=O)oc2c1',
#  'CCc1ccc(OC(C)C(=O)Nc2nonc2-c2ccc(OC)cc2)cc1',
#  'Cc1cc(O)c2c(C)c(CC(=O)NCc3cccc(Cl)c3)c(=O)oc2c1',
#  'CC(=O)C(C)Sc1ncnc2sc3c(c12)CCC(C)C3',
#  'CCN1CCN(Cc2c(C)[nH]c3ccc(N(CC)CC)cc3c2=O)CC1',
#  'C=CCOc1ccc(C(=O)Nc2nonc2-c2ccc(F)cc2)cc1',
#  'CCOC(=O)c1cnc2ccc(C(=O)OC)cc2c1NCCO',
#  'Cc1ccc(-c2cc(C(=O)N3CC(C)Oc4ccccc43)no2)cc1',
#  'Cc1ccc(-n2ncc3c(NNC(=O)CCc4ccccc4)ncnc32)cc1C',
#  'Cc1cccc(C)c1OCC(=O)Nc1nc(C)c(-c2nc(-c3cccs3)no2)s1',
#  'O=C1c2sc3nc4ccccc4n3c2C(=O)N1c1cc(Cl)ccc1Cl',
#  'Cc1[nH]c2ccc(Br)cc2c(=O)c1CN1CCC(C)CC1',
#  'Cc1ccc(-c2cc(C(=O)Nc3ccccn3)no2)cc1C',
#  'COC(=O)C(C)Oc1ccc2c(=O)c(Oc3cc(C)cc(C)c3C)coc2c1',
#  'Cc1cc(C)c2c(CC(=O)Nc3nc4ccc(S(C)(=O)=O)cc4s3)coc2c1',
#  'COc1cccc(Oc2ncnc3sc(-c4ccccc4)cc23)c1',
#  'Cc1ccc(-c2nnc(CNC(=O)COc3cc(C)c(Cl)c(C)c3)o2)cc1',
#  'CC1CCc2c(sc3ncnc(NCCc4nc5ccccc5[nH]4)c23)C1',
#  'O=C(NNc1ncnc2c1cnn2-c1ccc(Cl)c(Cl)c1)c1ccco1',
#  'O=C1c2ccccc2C(=O)N1CCSc1ncnc2sc(-c3ccccc3)cc12',
#  'Cc1ccc(-n2ncc3c2ncn2c(-c4cccc([N+](=O)[O-])c4)nnc32)c(C)c1',
#  'Cc1ccc(-n2ncc3c2ncn2c(-c4ccco4)nnc32)cc1',
#  'O=C(O)CCCN1C(=O)c2cccc3c(O)ccc(c23)C1=O',
#  'C=CCN1C(=O)COc2ccc(-c3nc(NC(=O)COC)sc3C)cc21',
#  'CCN1C(=O)COc2ccc(-c3nc(NC(C)=O)sc3C)cc21',
#  'CC12CCC3c4ccc(O)cc4CCC3C1CC(O)C2O',
#  'Cc1cc(NCc2ccc(C(=O)O)cc2)ncc1N.Cl.Cl',
#  'CC12CCC3c4ccc(OCc5ccc(F)cc5)cc4CCC3C1CC(O)C2O',
#  'Cc1nnc(SCCSc2nnc(C)n2N)n1N',
#  'Cc1oc2nc(SCC(=O)NCCCO)nc(N)c2c1C',
#  'Cc1c(C)n2c3c(=O)[nH]c(=O)n(C)c3nc2n1CCO',
#  'CS(=O)(=O)NCCc1csc(-c2ccncc2)n1',
#  'CC1=Nc2nc(CCCO)nn2C(c2ccc(Cl)cc2Cl)C1C(N)=O',
#  'OCCCCCNc1ncnc2ccc(Br)cc12',
#  'Cc1noc(C)c1Cn1cnc2sc(C(N)=O)c(C)c2c1=O',
#  'Cn1c(Sc2ncnc3[nH]cnc23)nc2c1c(=O)n(Cc1ccccc1)c(=O)n2C',
#  'COC(=O)c1ccc(CSc2nc(=O)c(CCO)c(C)[nH]2)cc1',
#  'Cc1oc2cc(O)ccc2c(=O)c1Oc1ccc(C(=O)O)cc1',
#  'O=c1cc(CSc2n[nH]c(=O)[nH]c2=O)[nH][nH]1',
#  'Nc1cc(=O)[nH]c(SCc2ccccc2CSc2nc(=O)cc(N)[nH]2)n1',
#  'Cc1cccc(OCCCn2cnc3sc(C(N)=O)c(C)c3c2=O)c1',
#  'Cn1c(SCCCO)nc2c1c(=O)n(Cc1ccc(Cl)cc1)c(=O)n2C',
#  'CC(=O)c1sc(NC(=O)CSc2nc(=O)c(CCO)c(C)[nH]2)nc1C',
#  'COc1ccc(CCNC(=O)Cn2cnc3sc(C(N)=O)c(C)c3c2=O)cc1OC',
#  'Cn1c(=O)[nH]c(=O)c2c1nc(NCc1cccnc1)n2CCO',
#  'COc1ccc(OCCn2ccc(=O)c(O)c2C)cc1',
#  'O=C(Cn1nnc2sc(-c3ccccc3)cc2c1=O)NCc1ccco1',
#  'COCCOC(=O)Cn1nnc2sc(-c3ccccc3)cc2c1=O',
#  'Cc1csc(NC(=O)c2cc(-c3cccs3)nc3c2cnn3C(C)C)n1',
#  'O=C(Cn1nnc2sc(-c3ccccc3)cc2c1=O)NCCc1ccccc1',
#  'COCCCNC(=O)c1cc(-c2ccccc2)nc2onc(C)c12',
#  'COc1ccc(Nc2nc(N3CCCC3)nc3c2cnn3C)cc1',
#  'CC(=O)c1cccc(NC(=O)c2cc(-c3ccccc3)nc3onc(C)c23)c1',
#  'Cc1noc2nc(-c3ccccc3)cc(C(=O)Nc3n[nH]c(CC(C)C)n3)c12',
#  'CCOC(=O)c1sc2ncnc(Nc3ccc(OC)cc3)c2c1C',
#  'COc1ccc2cnn(CC(=O)NC(C(=O)O)c3ccccc3)c(=O)c2c1OC',
#  'O=C(Cn1cnc2sc(-c3ccccc3)cc2c1=O)NCc1ccco1',
#  'CCOc1ccc2c(Cc3ccc(Cl)cc3)noc2c1',
#  'COc1ccc(Nc2nc(NC3CCCC3)nc3c2cnn3C)cc1',
#  'O=C(Cn1cnc2sc(-c3ccccc3)cc2c1=O)Nc1cc(C(F)(F)F)ccc1Cl',
#  'Cc1ccc(Sc2nc(N)c3nc(-c4ccccc4)oc3n2)cc1',
#  'CCOC(=O)c1sc2ncn(CC(=O)Nc3ccc(Cl)cc3C)c(=O)c2c1C',
#  'COC(=O)c1sc2ncn(Cc3cccc(C)c3)c(=O)c2c1C',
#  'O=C(Cn1cnc2sc(-c3ccccc3)cc2c1=O)NC1CCCCC1',
#  'CCOc1ccccc1NC(=O)Cn1cnc2sc(-c3ccccc3)cc2c1=O',
#  'O=C(Cn1nnc2sc(-c3ccccc3)cc2c1=O)Nc1ccccc1',
#  'O=c1c2cc(-c3ccccc3)sc2ncn1CCOc1ccccc1',
#  'Cc1cccc(OCc2nnc3sc(-c4ccncc4)nn23)c1',
#  'CCc1ccccc1NC(=O)CSc1n[nH]c2nc(=O)c(Cc3ccccc3Cl)nn12',
#  'CCOC(=O)c1sc2ncn(CC(=O)NC3CCCCC3)c(=O)c2c1C',
#  'COc1cc(NC(=O)c2cc(C3CC3)nc3onc(C)c23)cc(OC)c1',
#  'COc1ccc2cnn(CC(=O)NCCC3=CCCCC3)c(=O)c2c1OC',
#  'CCC(C)OC(=O)C(C)n1cnc2sc(-c3ccccc3)cc2c1=O',
#  'COc1ccc(-c2nn3c(COc4cccc(C)c4)nnc3s2)cc1OC',
#  'O=C(Cn1cnc2sc(-c3ccccc3)cc2c1=O)Nc1nc[nH]n1',
#  'Cc1ccc(OCc2nc(C)c(C(=O)NC(C)C)s2)cc1',
#  'O=C1NC(=O)c2cc(S(=O)(=O)NCc3ccco3)cc3cccc1c23',
#  'CN1C(=O)c2cccc3cc(S(=O)(=O)Nc4nccs4)cc(c23)C1=O',
#  'CCN1C(=O)c2cccc3cc(S(=O)(=O)Nc4ccccc4C(=O)OC)cc(c23)C1=O',
#  'Cc1cccc(NC(=O)CSc2nc3c4ccccc4ncn3n2)c1',
#  'Cc1cn2c3c(=O)n(C)c(=O)n(C)c3nc2n1CCc1ccccc1',
#  'COc1ccc(C(=O)Cn2c3ccccc3c3nc4ccccc4nc32)cc1',
#  'Cc1sc2ncnc(Sc3nnnn3-c3ccccc3)c2c1-c1ccccc1',
#  'Cc1sc2ncnc(Sc3nnnn3-c3ccccc3)c2c1C',
#  'Cc1sc2ncnc(NCCc3nc4ccccc4[nH]3)c2c1C',
#  'O=C1c2cccc3cccc(c23)C(=O)N1CCCc1nnc(Nc2ccccc2)s1',
#  'c1ccc(-n2nnnc2Sc2ncnc3c4c(sc23)CCCC4)cc1',
#  'Cc1cc(C(=O)NC(CC(C)C)c2nnc3ccccn23)c2c(C)noc2n1',
#  'O=C(c1ccc2noc(-c3ccccc3)c2c1)N1CCCc2ccccc21',
#  'Cc1cccc(Nn2c(N)c(C#N)c3nc4ccccc4nc32)c1',
#  'CCOC(=O)c1c(NC(=O)COc2ccccc2Br)sc2c1CCCC2',
#  'CCOc1ccccc1C(=O)Nc1ccccc1-c1nc(-c2ccc(F)cc2)no1',
#  'Cc1ccc(C(=O)Nc2ccccc2-c2nc(-c3ccc(C)cc3)no2)cc1',
#  'Cc1ccc(CNc2cc(C)nc(-n3nc(C)cc3C)n2)cc1',
#  'COc1ccc(CCNc2ncnc3sc(C)c(C)c23)cc1',
#  'Cc1sc2ncnc(SCCc3ccccc3)c2c1C',
#  'Cc1cc(OCc2nc(C#N)c(NCc3ccncc3)o2)ccc1Cl',
#  'C=CCn1c(=O)c2c(C)c(C)sc2n2c(Nc3ccc(OC)cc3)nnc12',
#  'CCCS(=O)(=O)c1nc(S(=O)(=O)c2ccc(C)cc2)c(NCc2ccco2)s1',
#  'Cc1cc(S(=O)(=O)NCc2ccc(-c3ccccc3F)o2)ccc1F',
#  'Cc1c(Cl)cccc1N=C1CSc2nnc(-c3ccccc3Br)n2N1',
#  'Cc1ccc(O)c(-c2[nH]nc3c2C(c2cccc(O)c2)N(Cc2ccco2)C3=O)c1',
#  'C=CCn1c(=O)c2c3c(sc2n2c(Nc4ccccc4)nnc12)CCC3',
#  'Cc1cc(C)c(S(=O)(=O)Nc2c(C)cccc2C)cc1N(C)S(=O)(=O)c1ccccc1',
#  'Cc1ccccc1OCC(=O)Nc1ccnc2cc(C(F)(F)F)ccc12',
#  'N=c1c(C(=O)NCC2CCCO2)cc2c(=O)n3ccccc3nc2n1Cc1ccco1',
#  'CCN1C(=O)c2cccc3cc(S(=O)(=O)Nc4ccccc4C)cc(c23)C1=O',
#  'Nc1nc(SCCCN2C(=O)c3cccc4cccc(c34)C2=O)nc2sc3c(c12)CCCC3',
#  'c1ccc2oc(SCCSc3nc4ccccc4o3)nc2c1',
#  'COc1cccc(C(=O)COc2cc(C)cc3oc(=O)c(C)c(C)c23)c1',
#  'COc1ccc(CNc2nc(N3CCCC3)c3cnn(C)c3n2)cc1OC',
#  'CCOC(=O)c1cnc2c(ccc3ccccc32)c1NCc1cccnc1',
#  'Brc1c(CSc2nc3ccccc3o2)nc2ccccn12',
#  'Cc1ccc(NS(=O)(=O)c2cc3c4c(cccc4c2)C(=O)NC3=O)cc1',
#  'Cc1sc2ncnc(SCCC(=O)NCc3cccs3)c2c1C',
#  'COc1ccc(CCNC(=O)CSc2ncnc3sc4c(c23)CCCC4)cc1',
#  'Cn1c(SCC(=O)c2ccc(Cl)cc2Cl)nnc1-c1cccnc1',
#  'CN1C(=O)c2cccc3c(S(=O)(=O)Nc4ccccn4)ccc1c23',
#  'COc1cc(NS(=O)(=O)c2ccc3c4c(cccc24)C(=O)N3C)cc(OC)c1',
#  'Cc1ccccc1NS(=O)(=O)c1ccc2c3c(cccc13)C(=O)N2C',
#  'CCOC(=O)c1cnc2ccc(F)cc2c1NCc1cccnc1',
#  'C=CCn1c(SCc2ccc3c(c2)OCO3)nc2sc(C)c(C)c2c1=O',
#  'CC(Nc1ncnc2ccc(Br)cc12)c1ccccc1',
#  'Cc1cc(C)n2c(SCc3nnnn3-c3ccccc3)nnc2n1',
#  'CCOC(=O)CCCSc1nc(N)c2c(C)c(Cc3ccccc3)sc2n1',
#  'Cc1nc(NCCc2ccccc2)c2c3c(sc2n1)CCC3',
#  'Cc1nc(SCC(=O)c2ccc3c(c2)OCO3)c2c3c(sc2n1)CCC3',
#  'O=C(CSc1ncnc2sc3c(c12)CCCC3)c1cccs1',
#  'COc1ccc(CCN=c2[nH]cnc3sc4c(c23)CCCC4)cc1.O=C(O)C(=O)O',
#  'Cc1csc2nc(CSc3nnnn3-c3ccccc3)c(Br)n12',
#  'COc1ccc2cc(NC(=O)CCCc3nnc4ccccn34)cnc2c1',
#  'CC(=O)Nc1ccc(Nc2ncnc3c2cnn3-c2ccc(C)cc2C)cc1',
#  'Cc1ccc(Cl)cc1-n1ncc2c(NCc3ccccc3)ncnc21',
#  'Nc1c(C(=O)NCc2ccccc2)c2nc3ccccc3nc2n1Cc1ccco1',
#  'CCOC(=O)c1cnc2c(ccc3ccccc32)c1NCCOC(=O)c1ccc(C)cc1',
#  'COc1ccccc1OCC(=O)Nc1c(C(=O)c2ccccc2)oc2ccccc12',
#  'c1ccc2c(c1)c(NCCCn1ccnc1)nn1cnnc21',
#  'CC(C)c1nc(Nc2ccc3c[nH]nc3c2)c2ccccc2n1',
#  'O=C(NCCCCCc1nnc2ccccn12)c1ccccc1-n1cnnn1',
#  'CCOc1cc(O)c(-c2[nH]ncc2-c2nc(C)cs2)cc1CC',
#  'COc1ccc(Nc2nc(Nc3cccc(Cl)c3)nc3nccnc23)cc1',
#  'CCOC(=O)c1cnc2ccc(C)cc2c1NCCc1ccccc1',
#  'Cc1ccc(-c2csc3ncnc(Nc4cccc(C(=O)O)c4)c23)cc1',
#  'Cc1cccc(Oc2ncnc3sccc23)c1',
#  'CCNc1nc(NCC)nc(Nc2ccc(C)c(C)c2)n1.Cl',
#  'O=C(c1cc(=O)c2ccccc2o1)N(Cc1cccc2ccccc12)c1ccccn1',
#  'Cc1sc2ncnc(N3CCN(Cc4ccccc4)CC3)c2c1C',
#  'Cc1ccc2[nH]c(C)cc(=NCc3cccnc3)c2c1.Cl.Cl',
#  'CC12CCC3c4ccc(O)cc4CCC3C1CCC2O',
#  'Fc1ccc(-n2ncc3c(NCCCc4ccccc4)ncnc32)cc1',
#  'Cc1cccc(N=C2CSc3nnc(-c4ccccc4Br)n3N2)c1C',
#  'O=C(Cn1nnc2sc(-c3ccccc3)cc2c1=O)NCc1ccccc1',
#  'COc1ccc2cnn(CC(=O)NCC3(CC(=O)O)CCCCC3)c(=O)c2c1OC',
#  'C=CCn1c(=O)c2c3c(sc2n2c(Nc4ccc(OC)cc4)nnc12)CCC3',
#  'Cc1noc2nc(-c3ccccc3)cc(C(=O)NCCCOC(C)C)c12',
#  'Cc1ccc(-c2csc3ncnc(Oc4ccc5c(c4)OCO5)c23)cc1',
#  'CCN1C(=O)c2cccc3cc(S(=O)(=O)Nc4cccc(C(=O)O)c4)cc(c23)C1=O',
#  'Cc1ccc(O)c(-c2[nH]nc3c2C(c2ccccc2F)N(Cc2ccco2)C3=O)c1',
#  'CC1=Nc2nc(CCCO)nn2C(c2ccccc2F)C1C(N)=O',
#  'C=CCOc1ccc(C(=O)Nc2ccccc2-c2nc(-c3ccc(F)cc3)no2)cc1',
#  'O=c1cc(CSc2n[nH]c(=O)[nH]c2=O)[nH][nH]1',
#  'Cc1sc2ncn3nnnc3c2c1-c1ccccc1',
#  'COC(=O)c1sc2ncn(Cc3cccc(Cl)c3)c(=O)c2c1C',
#  'COc1ccc(N2C(=O)c3sc4nc5ccccc5n4c3C2=O)cc1',
#  'CCOC(=O)c1cnc2ccc(F)cc2c1NCCc1ccc(OC)c(OC)c1',
#  'CCNC(=O)c1cc2c(=O)n3ccccc3nc2n(Cc2cccnc2)c1=N',
#  'COc1ccc(-c2csc3ncn(CC(=O)NCc4ccco4)c(=O)c23)cc1',
#  'COc1ccc(-c2nnc3c4cnn(-c5ccccc5C)c4ncn23)c(O)c1',
#  'O=C(CSc1ncnc2sc3c(c12)CCCC3)c1ccco1',
#  'Cc1cn2c3c(=O)n(Cc4ccccc4Cl)c(=O)n(C)c3nc2n1CCO',
#  'Cc1c(C)n2c3c(=O)[nH]c(=O)n(C)c3nc2n1CCCO',
#  'COc1cccc(CNC(=O)Cc2c(C)c3cc4c(C)c(C)oc4cc3oc2=O)c1',
#  'O=C(CSc1nnc2cc(-c3ccccc3)ncn12)Nc1ccccc1',
#  'Cn1c(Sc2ncnc3[nH]cnc23)nc2c1c(=O)n(Cc1ccc(Cl)cc1)c(=O)n2C',
#  'Cc1cc(C)n(-c2ccc3nnc(CCC(=O)Nc4nc(C)c(C)s4)n3n2)n1',
#  'COc1ccc(C(=O)NNc2ncnc3c2cnn3-c2ccc(C)c(C)c2)cc1OC',
#  'CC(C)c1n[nH]c(NC(=O)Cn2cnc3sc(-c4ccccc4)cc3c2=O)n1',
#  'Cc1nc(NCCc2ccccc2)c2c3c(sc2n1)CCCC3',
#  'C=CCN1C(=O)COc2ccc(-c3nc(NC(C)=O)sc3C)cc21',
#  'CCC(Oc1ccccc1F)C(=O)Nc1nonc1-c1ccc(OC)c(C)c1',
#  'COc1ccc(Nc2ncnc3sc(-c4ccccc4)cc23)cc1',
#  'COc1ccc(OCCCn2cnc3sc(C(N)=O)c(C)c3c2=O)cc1',
#  'CCOC(=O)c1cnc2c(C)c(C)ccc2c1NCc1ccccc1',
#  'Cc1nc(Sc2nnnn2-c2ccccc2)c2c3c(sc2n1)CCC3',
#  'Cc1ccc(Cl)cc1NC(=O)C(C)n1cnc2sc(-c3ccccc3)cc2c1=O',
#  'COc1ccccc1OCC(=O)Nc1c(C(=O)c2ccc(C)cc2)oc2ccccc12',
#  'Cc1sc2nc(SCCCN3C(=O)c4cccc5cccc(c45)C3=O)nc(N)c2c1C',
#  'CC12CCC3C(CCC4CCCCC43C)C1CCC2O',
#  'CC12CCCCC1CCC1C2CCC2(C)C1CCC2(C)O',
#  'O=c1[nH]c2c(c(=O)[nH]1)CN(Cc1ccccc1)CC2',
#  'COC(=O)CCC(C)C1CCC2C3CCC4CC(O)CCC4(C)C3CC(OC)C12C',
#  'COC(=O)C1CCC2C3CC=C4CC(O)CCC4(C)C3CCC12C',
#  'COC(=O)c1cc(Cl)nc2c1CN(Cc1ccccc1)CC2',
#  'CC(=O)OC1CCC2(C)C(=CCC3C2CCC2(C)C(C(=O)O)CCC32)C1',
#  'COC(=O)c1ccnc2c1CN(Cc1ccccc1)CC2',
#  'CCOC(=O)c1coc(-c2ccc(Cl)c(Cl)c2)n1',
#  'Nc1nc2c(s1)CN(Cc1ccccc1)CC2',
#  'CCOC(=O)c1cn2cc(F)ccc2n1',
#  'CCOC(=O)c1cn2c(Cl)cccc2n1',
#  'CCOC(=O)c1coc(-c2ccc(C(F)(F)F)cc2)n1',
#  'CCOC(=O)c1cn2c(-c3ccc(C)cc3)csc2n1',
#  'Cc1ccc2nc(-c3ccc(F)c(C)c3)c(CC(=O)O)n2c1',
#  'CCOC(=O)c1csc(-c2cc(Cl)ccc2O)n1',
#  'CC(=O)OC1CCC2(C)C(=CCC3C2CCC2(C)C3CCC2C2(C)CCC(=O)O2)C1',
#  'CC(=O)OC1CCC2(C)C(=CCC3C2CCC2(C)C3CCC2C2(C)CCC(=O)O2)C1',
#  'O=C(O)c1cc(C2CC2)n2nc(-c3ccccc3F)cc2n1',
#  'CCOC(=O)c1cn2cc(C)ccc2n1',
#  'O=C(O)c1cccn2cc(-c3ccccc3)nc12',
#  'N#Cc1c(N)sc2c1CCN(Cc1ccccc1)C2',
#  'O=[N+]([O-])c1ccc2c(c1)CN(Cc1ccccc1)CC2',
#  'CCOC(=O)c1cn2ccccc2n1',
#  'CCOC(=O)c1nn(-c2ccc(Cl)cc2)cc1O',
#  'CCOC(=O)c1cn2ccc(C)cc2n1',
#  'O=[N+]([O-])c1ccc2nc(-c3ccc(O)cc3)cn2c1',
#  'Cc1cc([N+](=O)[O-])c2nc(-c3ccc(-c4ccccc4)cc3)cn2c1',
#  'CCOC(=O)c1cc(-c2ccc(OC)cc2)c2c(C)nn(-c3ccccc3)c2n1',
#  'O=[N+]([O-])c1ccc2nc(-c3ccc(-c4ccccc4)cc3)cn2c1',
#  'O=[N+]([O-])c1cccn2cc(-c3ccc(-c4ccccc4)cc3)nc12',
#  'c1ccc(CN2CCc3[nH]ccc3C2)cc1',
#  'Oc1ccc(CN2CCc3ccccc3C2)cc1',
#  'Cc1cc(N)c2nc(-c3ccc(-c4ccccc4)cc3)cn2c1',
#  'Cc1ccc2nc(-c3ccc(F)c(C)c3)cn2c1',
#  'O=C(O)CSc1nnc(-c2ccc(Cl)cc2)n1-c1ccccc1',
#  'O=C(O)CSc1nnc(-c2ccc(Cl)cc2Cl)n1-c1ccccc1',
#  'Cc1ccc2nc(-c3cccc(N)c3)c(CN(C)C)n2c1.Cl.Cl.Cl',
#  'Fc1ccc(-c2cn3ccccc3n2)cc1',
#  'CCOC(=O)c1nn(-c2ccc(Br)cc2)cc1O',
#  'CC(C(=O)O)C1CCC2C3CCC4CC5CCC4(C)C3(O5)C(=O)CC12C',
#  'CC(C(=O)O)C1CCC2C3CCC4CC5CCC4(C)C3(O5)C(=O)CC12C',
#  'Cc1ccc(-c2cn3cc(C)ccc3n2)cc1',
#  'CC1(O)CCC(C(C)(C)O)CC1',
#  'O=[N+]([O-])c1ccc2nc(-c3ccccc3)cn2c1',
#  'Nc1ccc2nc(-c3ccc(F)cc3)cn2c1',
#  'Nc1cccn2cc(-c3ccc(-c4ccccc4)cc3)nc12',
#  'CCOC(=O)c1cn2c(n1)CCC2',
#  'Fc1ccc(-c2cn3cc(Cc4ccccc4F)sc3n2)cc1',
#  'Cc1cccn2cc(-c3ccc(Cl)c(Cl)c3)nc12',
#  'Nc1ccc2c(c1)CN(Cc1ccccc1)CC2',
#  'CCOC(=O)c1cnc(-c2ccc(C)cc2)s1',
#  'Nc1ccc2nc(-c3ccc(-c4ccccc4)cc3)cn2c1',
#  'O=c1cc(CSc2nnc(-c3ccc(Cl)cc3)n2-c2ccccc2)[nH][nH]1',
#  'COCc1nc2c(s1)CN(C(=O)c1ccccc1F)CC2',
#  'CCOC(=O)c1csc(NN=Cc2ccc(Cl)cc2)n1',
#  'CCOC(=O)c1sc(-c2ccccc2)nc1C(F)(F)F',
#  'Fc1ccc2nc(-c3ccc(Cl)cc3Cl)cn2c1',
#  'CCOC(=O)CSc1nnc(-c2ccccc2)n1-c1ccccc1',
#  'Cc1sc(-c2ccccc2F)nc1C(=O)N1CCN(C)CC1.Cl.Cl',
#  'Cc1ccn2cc(-c3ccc(F)cc3)nc2c1',
#  'CCOC(=O)c1c(C)nc2c(c1-c1ccc(Br)cc1)C(=O)CC(C)(C)C2',
#  'c1ccc(-c2cn3ccccc3n2)cc1',
#  'Cc1ccc(-c2nc3ccc(C)cn3c2C(=O)O)cc1',
#  'Cc1cc2nc(-c3ccc(F)cc3)cn2cc1N',
#  'CCOC(=O)c1nn(-c2ccc(F)cc2)c(-c2ccccc2)c1C#N',
#  'OCc1c(-c2ccc(Cl)cc2Cl)nc2ccccn12',
#  'Cc1ccc(-c2cn3cccc(C)c3n2)cc1C',
#  'CCOC(=O)c1sc(-c2ccc(F)cc2)nc1C',
#  'Cc1ccn2cc(-c3ccc(-c4ccccc4)cc3)nc2c1',
#  'C#Cc1ccc2c(c1)C(c1ccccn1)=NCc1c(C(=O)NC)ncn1-2',
#  'C#Cc1ccc2c(c1)C(c1ccccc1)=NCc1c(-c3nc(C(C)C)no3)ncn1-2',
#  'C#Cc1ccc2c(c1)C(c1ccccc1F)=NCc1c(C(=O)NC)ncn1-2',
#  'NCCCC(=O)O',
#  'Cc1ccc(CNC(=O)C(=O)c2c[nH]c3ccc([N+](=O)[O-])cc23)cc1',
#  'NCc1cn(O)nc1-c1ccc(-c2ccccc2)cc1',
#  'Cl.S=c1[nH]nc(C2CCNCC2)o1',
#  'C#Cc1ccc2c(c1)C(c1ccccc1)=NCc1c(C(=O)NC)ncn1-2',
#  'Oc1ccc2c(c1)CCN(CCCCc1ccccc1)CC2O',
#  'C#Cc1ccc2c(c1)C(c1ccccn1)=NCc1c(-c3nc(C(C)C)no3)ncn1-2',
#  'CC(C)(C)OC(=O)c1cc2c(cn1)[nH]c1ccccc12',
#  'CC(NC(=O)C(=O)c1c[nH]c2ccc([N+](=O)[O-])cc12)c1ccccc1',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(N)cc2)nc2c(Cl)cc(Cl)cn12.Cl',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)cc2)nc2c(NC(=O)CCCC(=O)O)cccn12',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)c([N+](=O)[O-])c2)nc2c(Cl)cc(Cl)cn12',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)cc2)nc2c(NC(=O)CC(=O)O)cccn12',
#  'Cc1ccc(-c2nc3ccc(F)cn3c2CC(=O)N(C)C)cc1',
#  'Cc1ccc2nc(-c3ccc(F)cc3)c(CC(=O)N(C)C)n2c1',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)c(N)c2)nc2c(Cl)cc(Cl)cn12',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(OC)cc2)nc2c(Cl)cc(Cl)cn12',
#  'CC1(CC(=O)O)CSC(=N)N1',
#  'CCC(C)N(C)C(=O)c1cc2ccccc2c(-c2ccccc2Cl)n1',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)cc2)nc2c(NC(=O)CN)cccn12.Cl',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(O)cc2)nc2c(Cl)cc(Cl)cn12',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc([N+](=O)[O-])cc2)nc2c(Cl)cc(Cl)cn12',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(N)cc2)nc2c(Cl)cc(Cl)cn12',
#  'CCCCN(C)C(=O)Cc1c(-c2ccc(Cl)c(N)c2)nc2c(Cl)cc(Cl)cn12',
#  'CCCCN(C)C(=O)Cc1c(-c2ccc(Cl)c([N+](=O)[O-])c2)nc2c(Cl)cccn12',
#  'CCCCN(C)C(=O)Cc1c(-c2ccc(Cl)c(N)c2)nc2c(Cl)cccn12',
#  'NCc1cnn(O)c1Cl',
#  'CCCCN(C)C(=O)Cc1c(-c2ccc(OC)cc2)nc2c(Cl)cc(Cl)cn12',
#  'COc1ccc2c(c1)CCc1cc(O)cc(OC)c1-2',
#  'COc1cc(O)cc(CCc2cccc(O)c2)c1',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)c(NC(=O)CCC(=O)O)c2)nc2c(Cl)cc(Cl)cn12',
#  'O=C(O)C1CCNCC1',
#  'CN1CCC2(O)c3cc(Br)ccc3N(C)C12c1ccccc1',
#  'COc1cc(CCc2ccc(O)cc2)cc(OC)c1',
#  'CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(F)ccc1-2',
#  'COc1cc(O)cc(C=Cc2cccc(O)c2)c1',
#  'CN(C(=O)Cc1c(-c2ccc(O)cc2)nc2c(Cl)cc(Cl)cn12)c1ccccc1',
#  'COc1ccc2c(c1)-n1ncc(C(=O)Nc3ccccc3)c1NC2',
#  'COC(=O)C1C(C)=NC(=S)NC1c1cccc(O)c1',
#  'O=C(NCc1ccc(F)cc1)C(=O)c1c[nH]c2ccccc12',
#  'NCCCCc1no[nH]c1=O',
#  'COc1cc(CCc2ccc(OC)c(OC)c2)cc(OC)c1',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)c(N)c2)nc2c(Cl)cc(Cl)cn12.Cl',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)cc2)nc2c(NC(=O)CCC(=O)OCC)cccn12',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(OC(=O)CN)cc2)nc2c(Cl)cc(Cl)cn12.Cl',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)cc2)nc2c(NC(=O)CCC(=O)O)cccn12',
#  'CCCN(CCC)C(=O)Cc1c(-c2nccs2)nc2c(Cl)cc(Cl)cn12',
#  'CCCCN(C)C(=O)Cc1c(-c2ccc(Cl)c([N+](=O)[O-])c2)nc2c(Cl)cc(Cl)cn12',
#  'CN(C(=O)Cc1c(-c2nccs2)nc2c(Cl)cc(Cl)cn12)c1ccccc1',
#  'CCCCN(C)C(=O)Cc1c(-c2ccc(O)cc2)nc2c(Cl)cc(Cl)cn12',
#  'O=C(Nc1c(-c2cccs2)nc2ccc(F)cn12)c1ccc(Cl)cc1',
#  'COc1ccc(-c2nc3c(Cl)cc(Cl)cn3c2CC(=O)N(C)c2ccccc2)cc1',
#  'CN1C(=O)CN=C(c2ccccc2)c2cc(Cl)ccc21',
#  'CCOC(=O)c1cncn1C(C)c1ccc(C2(C(F)(F)F)N=N2)cc1',
#  'Cl.NCC(Cl)CC(=O)O',
#  'Cl.NCC(Br)CC(=O)O',
#  'Cc1c(CN)o[nH]c1=O',
#  'CCCN(CCC)C(=O)Cc1c(-c2ccc(OC(=O)CCC(=O)OC)cc2)nc2c(Cl)cc(Cl)cn12',
#  'O=C(NC1CCc2ccccc21)C(=O)c1c[nH]c2ccc([N+](=O)[O-])cc12',
#  'O=C(Nc1c(-c2ccccc2)nc2ccccn12)c1ccccc1',
#  'NCCCc1no[nH]c1=O',
#  'O=C(Nc1c(-c2cccs2)nc2ccc(I)cn12)c1ccc(Cl)cc1',
#  'CCOC(=O)C1=C(C)N(C)C(=S)NC1c1cccc(O)c1',
#  'COC(=O)C1C(C)=NC(=O)NC1c1ccccc1',
#  'CCOC(=O)C1C(C)=NC(=O)NC1c1cccc(O)c1',
#  'COc1ccc2c(c1)-n1ncc(C(=O)NCc3ccco3)c1NC2',
#  'CN1CCC2(O)c3cc(I)ccc3N(C)C12c1ccccc1',
#  'CCOC(=O)C1C(C)=NC(=S)NC1c1cccc(O)c1',
#  'CCn1cc(-c2cccc(C(F)(F)F)c2)c2sc(C(=N)NC3CCS(=O)(=O)CC3)cc2c1=O',
#  'NCCc1no[nH]c1=O',
#  'CCOC(=O)C1C(C)=NC(=S)NC1c1ccc(O)c(O)c1',
#  'NC1(C(=O)O)C(F)CC2C(C(=O)O)C21',
#  'CCC1CN2CCC3(O)C(=Nc4cccc(-c5ccoc5)c43)C2CC1C(=COC)C(=O)OC',
#  'COc1ccc2cnc3c(C(=O)NCc4cccs4)cnn3c2c1',
#  'CCOC(=O)C1C(CC)=NC(=S)NC1c1cccc(O)c1',
#  'CN(C)C(=O)Cc1c(-c2ccc(F)cc2)nc2ccc(F)cn12',
#  'O=C(Nc1c(-c2cccs2)nc2ccc(-c3cccs3)cn12)c1ccccc1',
#  'Cc1ccc2nc(-c3cccs3)c(NC(=O)c3ccc(Cl)cc3)n2c1',
#  'O=C(Nc1c(-c2cccs2)nc2ccc(Br)cn12)c1ccc(Oc2ccccc2)cc1',
#  'O=C(Nc1c(-c2cccs2)nc2ccc(Br)cn12)c1ccccc1',
#  'CCC1CN2CCC3(O)C(=Nc4cccc(C)c43)C2CC1C(=COC)C(=O)OC',
#  'COc1ccc2cnc3c(C(=O)NCc4ccco4)cnn3c2c1',
#  'O=C(Nc1c(-c2cccs2)nc2ccc(-c3ccccc3)cn12)c1ccccc1',
#  'CCC1CN2CCC3(O)C(=Nc4cccc(-c5ccccc5)c43)C2CC1C(=COC)C(=O)OC',
#  'CC1CCC(C(C)C)C(OC(=O)OC(C)OC(=O)C2C3CC(F)C(N)(C(=O)O)C32)C1',
#  'O=C(Nc1c(-c2cccs2)nc2cc(Br)ccn12)c1ccc(Cl)cc1',
#  'O=C(Nc1c(C2CCCC2)nc2ccc(Br)cn12)c1ccccc1',
#  'O=C(Nc1c(-c2cccs2)nc2ccc(C(F)(F)F)cn12)c1ccc(Cl)cc1',
#  'O=C(O)CC1CCNC1',
#  'N=C1NC(CC(=O)O)CS1',
#  'NCc1cnn(O)c1',
#  'COC(c1ccc(C(C)=O)cc1)C(F)(F)C(=O)C12CC3CC(CC(C3)C1)C2',
#  'O=C(O)C1=CCNCC1',
#  'CC(=O)c1ccc(C(O)C(F)(F)C(=O)C23CC4CC(CC(C4)C2)C3)cc1',
#  'CCCC=CC(O)C(F)(F)C(=O)c1ccc(Cl)cc1',
#  'CC=CC=CC(O)C(F)(F)C(=O)C=CCCCC',
#  'CC(C)c1cccc(C(C)C)c1O',
#  'NCc1cnn(O)c1Br',
#  'NCc1cn(O)nc1-c1ccccc1',
#  'NCc1cn(O)nc1Cc1ccccc1',
#  'O=C(O)CC1CN=CN1',
#  'CC1SC(=N)NC1CC(=O)O',
#  'Oc1c(Br)cc(Br)cc1-c1cc(Br)cc(Br)c1O',
#  'Cl.NCc1n[nH]c(=O)o1',
#  'CCc1nc(N)ccc1C(=O)O',
#  'CC(C(=O)O)C1CSC(=N)N1',
#  'CC(C(=O)O)C1CSC(=N)N1',
#  'CC(C)(O)C(=O)c1oc2nc(-c3ccc(Cl)cc3Cl)c(-c3ccc(Cl)cc3)cc2c1NC(=O)CO',
#  'O=c1[nH]oc2c1CCNC2',
#  'N=C1NC(CC(=O)O)CS1',
#  'Cc1nc(N)ccc1C(=O)O',
#  'Nc1ccc(C(=O)O)c(-c2ccccc2)n1',
#  'NCc1cn(O)nc1-c1cccc(-c2ccccc2)c1',
#  'NCc1cc(=O)[nH]o1',
#  'CP(=O)(O)C1(O)CC(N)C1',
#  'CP(=O)(O)C1CC(N)C1',
#  'O=C(O)Cc1c[nH]cn1',
#  'Nc1ccc(C(=O)O)c(Cl)n1',
#  'N=C1CCC(C(=O)O)CN1',
#  'CCCCc1nc(N)ccc1C(=O)O',
#  'NCC=CC(=O)O',
#  'CCc1cc(N)ncc1C(=O)O',
#  'CC(C)CC(=O)C(F)(F)C(NC(=O)OC(C)(C)C)c1ccccc1',
#  'CC(C)(C)OC(=O)NC(c1ccccc1)C(F)(F)C(=O)c1ccc2c(c1)OCO2',
#  'NC1=NCC(C(=O)O)CN1',
#  'CP(=O)(O)C1(O)CC(N)C1',
#  'CCc1ccc(C(O)C(F)(F)C(=O)C23CC4CC(CC(C4)C2)C3)cc1',
#  'Nc1ccc(C(=O)O)cn1',
#  'CCCCc1cc(N)ncc1C(=O)O',
#  'CCc1cc(C(=O)O)cnc1N',
#  'Cc1cc(N)ncc1C(=O)O',
#  'Nc1ncc(C(=O)O)cc1I',
#  'Cc1cc(C(=O)O)cnc1N',
#  'COc1ccc(C(O)C(F)(F)C(=O)c2ccc3ccccc3c2)cc1',
#  'CCCC=CC(O)C(F)(F)C(=O)c1ccc2ccccc2c1',
#  'NCC(CC(=O)O)c1ccc(Cl)cc1',
#  'CC(CC(O)C(F)(F)C(=O)c1ccc2c(c1)OCO2)O[Si](C(C)C)(C(C)C)C(C)C',
#  'NCC(CC(=O)O)c1ccc(Cl)cc1',
#  'On1cc2c(n1)CCNC2',
#  'NCc1cn(O)nc1CCc1ccccc1',
#  'O=C(C12CC3CC(CC(C3)C1)C2)C(F)(F)C(O)c1ccccc1',
#  'NCc1cn(O)nc1N',
#  'NCc1cn(O)nc1I',
#  'CCc1nn(O)cc1CN',
#  'CC(=O)c1ccc(C(O)CC(=O)C23CC4CC(CC(C4)C2)C3)cc1',
#  'CNc1ccc(C(=O)O)cn1',
#  'Cc1c(CN)cnn1O',
#  'O=C(C12CC3CC(CC(C3)C1)C2)C(F)(F)C(O)C=Cc1ccccc1',
#  'CC(C)(C)c1cc(C(C)(C)C)c2c(c1)C(O)(C(F)(F)F)C(=O)O2',
#  'On1ncc2c1CCNC2',
#  'NCc1cn(O)nc1CCc1ccncc1',
#  'Cc1nn(O)cc1CN',
#  'CC=CC=CC(O)C(F)(F)C(=O)c1ccc2ccccc2c1',
#  'O=C(c1ccc2ccccc2c1)C(F)(F)C(O)C1CCCCC1',
#  'O=C(C12CC3CC(CC(C3)C1)C2)C(F)(F)C(NS(=O)(=O)c1ccccc1)c1ccccc1',
#  'CC(C)(C)OC(=O)NC(c1ccccc1)C(F)(F)C(=O)c1ccc2ccccc2c1',
#  'O=C(C12CC3CC(CC(C3)C1)C2)C(F)(F)C(O)c1ccc(Cl)cc1',
#  'CC1(C)C2CCC(C(O)C(F)(F)C(=O)c3ccc4c(c3)OCO4)C1C2',
#  'Cc1nn(O)c(C)c1CN',
#  'O=C(c1ccc2ccccc2c1)C(F)F',
#  'CC=CC=CC(O)C(F)(F)C(=O)C(C)(C)C',
#  'CC(=O)c1ccc(C(O)C(F)(F)C(=O)c2ccccn2)cc1',
#  'Nc1cc(-c2ccccc2)c(C(=O)O)cn1',
#  'O=C1c2ccccc2C(=O)N1CC(O)C(F)(F)C(=O)C12CC3CC(CC(C3)C1)C2',
#  'O=C(c1ccc(Cl)cc1)C(F)(F)C(NCc1ccccc1)c1ccccc1',
#  'O=C(c1ccc2ccccc2c1)C(F)(F)C(NS(=O)(=O)c1ccccc1)c1ccccc1',
#  'CC=CC=CC(NCc1ccccc1)C(F)(F)C(=O)c1ccc2ccccc2c1',
#  'O=C(c1ccc2ccccc2c1)C(F)(F)C(NCc1ccccc1)c1ccccc1',
#  'Clc1ccc(COc2c3cnc4c(c3nn2-c2ccc(Cl)cc2)CCCC4)cc1',
#  'Fc1ccc(COc2c3cnc4c(c3nn2-c2ccc(Cl)cc2)CCCC4)cc1',
#  'Fc1ccccc1-n1nc2c(cnc3ccccc32)c1OCc1ccccc1Cl',
#  'Fc1ccccc1COc1c2cnc3c(c2nn1-c1ccc(Cl)cc1)CCCC3',
#  'CC(C)(O)C(=O)c1oc2nc(-c3ccccc3Cl)c(-c3ccc(Cl)cc3)cc2c1NC(=O)CO',
#  'Clc1ccc(-n2nc3c4c(ncc3c2OCc2ccccc2Cl)CCCC4)cc1',
#  'Clc1ccc(-n2nc3c4c(ncc3c2Oc2ccccc2Cl)CCCC4)cc1',
#  'Clc1ccc(-n2nc3c4c(ncc3c2OCc2ccccc2Cl)CCOC4)cc1',
#  'Clc1ccc(-n2nc3c(cnc4ccccc43)c2OCC2CC2)cc1',
#  'CC1(C)CCc2ncc3c(OCc4ccccc4Cl)n(-c4ccc(Cl)cc4)nc3c2C1',
#  'Clc1ccc(-n2nc3c4c(ncc3c2OCc2ccccc2Cl)CCCCC4)cc1',
#  'Clc1ccc(-n2nc3c4c(ncc3c2OCc2cccc(Cl)c2)CCCC4)cc1',
#  'FC(F)(F)c1ccccc1COc1c2cnc3c(c2nn1-c1ccc(Cl)cc1)CCCC3',
#  'Clc1ccc(-n2nc3c4c(ncc3c2OCC2CC2)CCCC4)cc1',
#  'Clc1ccc(-n2nc3c(cnc4ccccc43)c2OCc2ccccc2Cl)cc1',
#  'Clc1ccccc1COc1c2cnc3ccccc3c2nn1-c1ccc2c(c1)OCO2',
#  'Clc1ccc(-n2nc3c(cnc4ccc(-n5ccnc5)cc43)c2OCC2CC2)cc1',
#  'CCCCNC(=O)c1cc(-c2ccc(F)cc2F)ccc1O',
#  'CC(=O)NCCCCNC(=O)CCCN.Cl',
#  'Cl.Cl.NCCCC(=O)NCCNC(=O)CCCN',
#  'NCCCC(N)=O.O=C(O)C(F)(F)F',
#  'Cl.Cl.NCCCC(=O)NCCCCCCNC(=O)CCCN',
#  'CCCCNC(=O)CCCN.Cl',
#  'Cl.Cl.NCCCCNC(=O)CCCN',
#  'CC(C)c1cc(CCCC2(C)N=N2)cc(C(C)C)c1O',
#  'CCOC(=O)c1cncn1C(C)c1ccccc1',
#  'CCOC(=O)c1cncn1C(C)c1ccc(C2(C(F)(F)F)N=N2)cc1',
#  'O=c1cc(-c2cccc([N+](=O)[O-])c2)oc2ccc(Br)cc12',
#  'O=c1cc(C2CCNCC2)o[nH]1',
#  'Cl.On1cc(C2CCNCC2)cn1',
#  'COc1ccccc1-c1oc2ccc(C)cc2c(=O)c1O',
#  'CCOC(=O)c1cncn1C(C)c1ccc(C2(C(F)(F)F)N=N2)cc1',
#  'Oc1ccccc1',
#  'CC(C)c1ccccc1O',
#  'Cc1ccc2c(c1)Oc1sc(Cl)cc1C(N1CCN(CC(C)(C)C(=O)O)CC1)=N2',
#  'CCOC(=O)c1ncc2[nH]c3cccc(OC(C)C)c3c2c1C',
#  'CC1SC(=N)NC1CC(=O)O',
#  'Nc1nc(CC(=O)O)cs1',
#  'O=C(Nc1c(-c2cccs2)nc2c(Br)cc(Br)cn12)c1ccc(Cl)cc1',
#  'O=C(Nc1c(-c2cccs2)nc2ccccn12)c1ccc(Cl)cc1',
#  'N=C1NC(CC(=O)O)CS1',
#  'CC(C(=O)O)C1CSC(=N)N1',
#  'O=C(O)CC1CCNC1',
#  'NC1=NC(CC(=O)O)CN1',
#  'COc1ccc(S(=O)(=O)Nc2c(C)cc(C)cc2C)cc1',
#  'NCC=CC(=O)O',
#  'Cl.O=C(O)C1=CCNCC1',
#  'CNCc1ccc(NC(=O)c2c[nH]c3c2C(=O)CCC3)cc1.Cl',
#  'Cc1ncsc1CCCl',
#  'O=C1N=C(N2CCOCC2)CN1c1ccc(Cl)cc1',
#  'CC(=O)NCCCS(=O)(=O)[O-].CC(=O)NCCCS(=O)(=O)[O-].[Ca+2]',
#  'C1CNCCN1.C1CNCCN1.C1CNCCN1.O=C(O)CC(O)(CC(=O)O)C(=O)O.O=C(O)CC(O)(CC(=O)O)C(=O)O',
#  'COc1ccc(OC)c(CN(C(C)=O)c2cc(F)ccc2Oc2ccccc2)c1',
#  'NC(=O)CCCN=C(c1ccc(Cl)cc1)c1cc(F)ccc1O',
#  'CCOC(=O)c1cncn1C(C)c1ccccc1',
#  'CCOC(=O)c1cncn1C(C)c1ccccc1.Cl',
#  'Cc1ccccc1-n1c(CF)nc2ccc(N)cc2c1=O',
#  'CC(C)=CCCC(C)(OC1OC(COC2OC(CO)C(O)C2O)C(O)C(O)C1O)C1CCC2(C)C1C(O)CC1C3(C)CCC(OC4OC(CO)C(O)C(O)C4OC4OC(CO)C(O)C(O)C4O)C(C)(C)C3CCC12C',
#  'NCCCC(=O)O',
#  'CC(C)=CC1CC(C)(O)C2C3CCC4C5(C)CCC(OC6OCC(O)C(OC7OC(COC8OC(CO)C(O)C(O)C8O)C(O)C(O)C7OC7OCC(O)C(O)C7O)C6OC6OC(C)C(O)C(O)C6O)C(C)(C)C5CCC4(C)C34COC2(C4)O1',
#  'C=C(C)c1cc2ccc3c(c2c(O)c1O)CCCC3(C)C',
#  'COc1cc(C=CC(=O)O)cc(OC)c1OC',
#  'NCc1cc(=O)[nH]o1',
#  'CC(C)c1cccc(C(C)C)c1O',
#  'CN1C(=O)CN=C(c2ccccc2)c2cc(Cl)ccc21',
#  'Cc1ccc(-c2nc3ccc(C)cn3c2CC(=O)N(C)C)cc1',
#  'Cn1ncnc1COc1nn2c(-c3cc(F)ccc3F)nnc2cc1C(C)(C)C',
#  'O=c1[nH]oc2c1CCNC2',
#  'Br.NCc1cc(=O)[nH]o1',
#  'O=S(=O)(O)C1CCNCC1',
#  'O=C(O)C1CCNCC1',
#  'Cn1c2ccc(F)cc2c2c(C(=O)N3CCCC3)cn(-c3ccccc3)c(=O)c21',
#  'CON=C1CC2(CC3CC(CC=C(C)CC(C)C=CC=C4COC5C(O)C(C)=CC(C(=O)O3)C45O)O2)OC(C(C)=CC(C)C)C1C',
#  'CC(O)C(=O)O',
#  'CC(O)CC(=O)O',
#  'CC(=O)C(=O)O',
#  'O=C(O)CCC(=O)C(=O)O',
#  'O=C(O)CO',
#  'O=C(O)CC(O)(CC(=O)O)C(=O)O',
#  'O=C(O)C1(O)CC(O)C(O)C(O)C1',
#  'O=C(O)C12CCNCC1O2',
#  'NN=CSC=CC(=O)O',
#  'NCCCS(=O)(=O)O',
#  'O=C(O)CCC(=O)OC1N=C(c2ccccc2Cl)c2cc(Br)ccc2NC1=O',
#  'CC1N=C(c2ccccc2F)c2cc(Br)ccc2NC1=O',
#  'CC(C)(C)OC(=O)NCc1n[nH]c(=O)o1.NCc1n[nH]c(=O)o1',
#  'CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(N=[N+]=[N-])ccc1-2']

# %%
smiles_antagonist = pd.read_csv('stan_data.csv')[609:]['stan_smiles'].tolist()

# %%
smiles_antagonist
# Out:
# ['Br.O=c1[nH]oc(C2CCNCC2)c1-c1cccc([N+](=O)[O-])c1',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1csc(-c2ccccc2)c1',
#  'Br.CC(C)(C)c1ccc(-c2c(C3CCNCC3)o[nH]c2=O)cc1',
#  'O=c1[nH]oc(C2CCNCC2)c1-c1cccc2ccccc12',
#  'NC(=O)C1=CCC(N)C1',
#  'NC1CC=C(C(=O)O)C1',
#  'CCCCCNC(=O)C1=CCC(N)C1',
#  'O=P1(O)CCC(CO)C1',
#  'CCONC(=O)C1=CCC(N)C1',
#  'N=c1ccc(-c2cccc(OCc3ccccc3)c2)nn1CCCC(=O)O',
#  'Br.Cc1nn(O)cc1C1CCNCC1',
#  'N=c1ccc(-c2cccc(N)c2)nn1CCCC(=O)O',
#  'CCOC(=O)c1ncn2c1CN=C(c1ccc(F)cc1)c1cc(F)ccc1-2',
#  'CCCCP(=O)(O)C1=CCC(N)C1',
#  'CC1=NN=C(c2cc3c(C(F)(F)F)cccc3s2)c2cc3oc(=O)[nH]c3cc2C1',
#  'c1ccc2c(NCCCCCCCNc3c4c(nc5ccccc35)CCCC4)c3c(nc2c1)CCCC3',
#  'O=c1[nH]oc(C2CCNCC2)c1Cc1ccc2ccccc2c1-c1ccccc1',
#  'Br.Br.Nc1cccc(-c2c(C3CCNCC3)o[nH]c2=O)c1',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1cccnc1',
#  'O=c1[nH]oc(C2CCNCC2)c1C(Br)c1ccc2ccccc2c1',
#  'Cl.O=c1[nH]nc(C2CCNCC2)o1',
#  'CCCC(O)CCC=CC=CC#CC#CC=CCO',
#  'CCCCP(=O)(O)C1=CCC(NC(=O)CCCCCNc2ccc([N+](=O)[O-])c3nonc23)C1',
#  'COc1ccc2cnc3c(C(=O)NCc4ccccc4OC)cnn3c2c1',
#  'Br.On1ncc(C2CCNCC2)c1-c1ccccc1',
#  'O=c1[nH]oc(C2CCNCC2)c1Cc1ccc2ccccc2c1Br',
#  'Cc1cccc(-c2nn(O)cc2C2CCNCC2)c1.Cl',
#  'Cl.On1ncc(C2CCNCC2)c1-c1cccc(-c2ccccc2)c1',
#  'O=c1[nH]oc(C2CCNCC2)c1-c1ccccc1',
#  'Cl.On1ncc(C2CCNCC2)c1Cc1ccc2ccccc2c1Br',
#  'O=C(O)C1CCP(=O)(O)C1',
#  'CCCNC(=O)C1=CCC(N)C1',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1ccc(Oc2ccccc2)cc1',
#  'Br.Cc1ccc(-c2nn(O)cc2C2CCNCC2)cc1',
#  'Cl.On1ncc(C2CCNCC2)c1Cc1ccc2ccccc2c1',
#  'CONC(=O)C1=CCC(N)C1',
#  'NC1CC=C(C(O)=NO)C1',
#  'CCOC(=O)c1ncn2c1CN=C(c1ccc(Cl)cc1)c1ccccc1-2',
#  'Cl.On1nc(-c2ccccc2)c(C2CCNCC2)c1Cc1ccc2ccccc2c1',
#  'Cc1ccccc1-c1nn(O)cc1C1CCNCC1.Cl',
#  'CN1C(=O)C2CN(S(=O)(=O)c3ccc4occc4c3)CC2c2cnccc21',
#  'N=C(N)NC1CCP(=O)(O)C1',
#  'NC1CCP(=O)(O)C1',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1cccc(Cl)c1',
#  'N=c1ccc(-c2ccc(O)cc2)nn1CCCC(=O)O',
#  'COc1ccc(-c2ccc(=N)n(CCCC(=O)O)n2)cc1',
#  'N=c1ccc(-c2ccccc2)nn1CCCC(=O)O',
#  'N=c1ccc(-c2cccc([N+](=O)[O-])c2)nn1CCCC(=O)O',
#  'O=c1[nH]oc(C2CCNCC2)c1-c1cccc(-c2ccccc2)c1',
#  'On1cc(C2CCNCC2)c(-c2cn(Cc3ccccc3)c(-c3ccccc3)n2)n1',
#  'On1cc(C2CCNCC2)cn1',
#  'CP(=O)(O)C1=CCNCC1',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1cc(Cl)cc(Cl)c1',
#  'CN1C(=O)C2CN(S(=O)(=O)c3ccc4c(c3)OCO4)CC2c2cnccc21',
#  'Cl.On1cc(C2CCNCC2)c(-c2cccc(-c3ccccc3)c2)n1',
#  'On1ncc(C2CCNCC2)c1-c1cn(Cc2ccccc2)c(-c2ccccc2)n1',
#  'CCCC(O)CCC=CC=CC#CC#CCCCO',
#  'On1cc(C2CCNCC2)c(-c2c[nH]c(-c3ccccc3)n2)n1',
#  'Br.On1cc(C2CCNCC2)c(-c2ccc(-c3ccccc3)cc2)n1',
#  'Br.On1cc(C2CCNCC2)c(-c2ccccc2)n1',
#  'Cl.Cn1c(N)c2[nH]c(=O)n(C)c2nc1=O',
#  'Br.On1cc(C2CCNCC2)c(Cc2ccc3ccccc3c2)n1',
#  'O=c1[nH]oc(C2CCNCC2)c1Cc1ccc2ccccc2c1',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1ccsc1',
#  'COc1ccc2c(c1)-n1ncc(C(=O)NCc3ccccc3)c1NC2',
#  'N=c1ccc(-c2cccc(O)c2)nn1CCCC(=O)O',
#  'O=c1[nH]oc(C2CCNCC2)c1-c1ccc2ccccc2c1',
#  'O=S(=O)(O)C1CCNCC1',
#  'CCOC(=O)c1ncn2c1CN=C(c1cccc([N+](=O)[O-])c1)c1cc(F)ccc1-2',
#  'CCOC(=O)c1ncn2c1CN=C(c1ccc(C)cc1)c1ccccc1-2',
#  'On1cc(C2CCNCC2)c(-c2c[nH]cn2)n1',
#  'On1cc(C2CCNCC2)c(-c2cccc(-c3ccccc3)c2)n1',
#  'N=c1ccc(-c2cccc(Cl)c2)nn1CCCC(=O)O',
#  'Br.On1nc(Cc2ccc3ccccc3c2)c(C2CCNCC2)c1-c1ccccc1',
#  'On1ncc(C2CCNCC2)c1-c1cn(Cc2ccccc2)c(Cl)n1',
#  'Cc1ccc(NC(=O)C2=CCC(N)C2)cc1',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1ccc(Cl)cc1',
#  'COc1ccc2c(c1)-n1ncc(C(N)=O)c1NC2',
#  'On1ncc(C2CCNCC2)c1-c1c[nH]c(-c2ccccc2)n1',
#  'On1ncc(C2CCNCC2)c1-c1c[nH]cn1',
#  'CCCCP(=O)(O)C1=CCC(NC(=O)CCCCCNC(=O)c2ccccc2NC)C1',
#  'COc1ccc2cnc3c(C(=O)NCC4CCCCC4)cnn3c2c1',
#  'COc1ccc2cnc3c(C(=O)OCc4ccccc4OC)cnn3c2c1',
#  'CN1C(=O)C2CN(S(=O)(=O)c3ccc4c(c3)OCO4)CC2c2cnccc21',
#  'NCC1CCP(=O)(O)C1',
#  'N=c1ccc(-c2ccc([N+](=O)[O-])cc2)nn1CCCC(=O)O',
#  'CP(=O)(O)OCCN',
#  'CCCCP(=O)(O)C1=CCC(N)C1',
#  'CCCCP(=O)(O)C1=CCC(NC(=O)CCCCCNC(=O)c2ccccc2NC)C1',
#  'CCCCP(=O)(O)CCCN',
#  'On1cc(C2CCNCC2)c(-c2cn(Cc3ccccc3)cn2)n1',
#  'CCCCP(=O)(O)C1=CCC(NC(=O)CCCCCNC(=O)CCCCC2SCC3NC(=O)NC32)C1',
#  'CN1CCc2cc3c(cc2C1C1OC(=O)c2c1ccc1c2OCO1)OCO3',
#  'COc1ccc2c(c1)-n1ncc(C(=O)NCc3ccccc3OC)c1NC2',
#  'Cl.On1cc(C2CCNCC2)c(Cc2ccccc2)n1',
#  'CCOC(=O)C1(C#N)C(c2ccccc2)Cc2c(c3ccccc3n2C(=O)OC(C)(C)C)C1CC=O',
#  'Cc1nccn1CC1CCc2c(c3ccccc3n2C)C1=O',
#  'C=CCONC(=O)C1=CCC(N)C1',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1ccc(-c2ccccc2)cc1',
#  'CC1(C)CC(=O)c2c(SCCO)sc(-c3nccs3)c2C1',
#  'N.N.N.N.Nc1ncnc2c1ncn2C1OC(COP(=O)(O)CP(=O)(O)OP(=O)(O)O)C2OC3(CCCCC3)OC21',
#  'CCCCCSc1nnc(COc2ccc3c(c2)CCC(=O)N3)o1',
#  'CNC(=O)c1ccc(N2C(=S)N(c3ccc(C#N)c(C(F)(F)F)c3)C(=O)C2(C)C)cc1F',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1cccc(-c2ccccc2)c1',
#  'CCCCP(=O)(O)C1=CCC(NC(=O)CCCCCNC(=O)CCC2=C3C(C)=CC(C)=[N+]3[B-](F)(F)n3c(C)cc(C)c32)C1',
#  'COc1ccc2c(c1)-n1ncc(C(=O)NC(C)C)c1NC2',
#  'CC1(C)OC2C(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)OC(n3cnc4c(N)ncnc43)C2O1.N.N.N.N',
#  'On1cc(C2CCNCC2)c(-c2cn(Cc3ccccc3)c(Cl)n2)n1',
#  'CNC(=O)C1=CCC(N)C1',
#  'Cc1ccc2c(c1)c1c3n2CCNC3CCC1',
#  'N=c1ccc(-c2ccc(Cl)cc2)nn1CCCC(=O)O',
#  'N=c1ccc(-c2ccc(OCc3ccccc3)cc2)nn1CCCC(=O)O',
#  'On1ncc(C2CCNCC2)c1-c1cccc(-c2ccccc2)c1',
#  'Br.O=c1[nH]oc(C2CCNCC2)c1-c1ccccc1Cl',
#  'COc1ccc2cnc3c(C(=O)NC(C)C)cnn3c2c1',
#  'COc1ccc2cnc3c(C(N)=O)cnn3c2c1',
#  'CCOC(=O)C1(C#N)C(c2ccccc2)Cc2c(c3ccccc3n2Cc2ccccc2)C1CC=O',
#  'Cc1cc(-c2nncc3c(C(C)(C)C)c(OCc4ncnn4C)nn23)no1',
#  'C[N+]1(C)CCc2cc3c(cc2C1C1OC(=O)c2c1ccc1c2OCO1)OCO3.[Br-]',
#  'Br.COc1ccc(-c2ccc(=N)n(CCCC(=O)O)n2)cc1',
#  'CC(C)(C)C(=O)NCCCC(=O)O',
#  'Cc1cc(C2=NOC(c3cc(Cl)c(Cl)c(Cl)c3)(C(F)(F)F)C2)sc1C(=O)NCC(=O)NCC(F)(F)F',
#  'CC1=NN=C(c2cc3c(F)cccc3s2)c2cc3oc(=O)[nH]c3cc2C1',
#  'CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(F)ccc1-2',
#  'NS(=O)(=O)c1cc(C(=O)O)c(NCc2ccco2)cc1Cl',
#  'NS(=O)(=O)c1cc(C(=O)[O-])c(NCc2ccco2)cc1Cl.[Na+]',
#  'C=C(C)C1C2OC(=O)C1C1(O)CC3OC34C(=O)OC2C14C',
#  'CN1CCc2cc3c(cc2C1C1OC(=O)c2c1ccc1c2OCO1)OCO3',
#  'COc1c(OC2OC(CO)C(O)C(O)C2O)cc2c(c1OC)-c1ccc(SC)c(=O)cc1C(NC(C)=O)CC2',
#  'O=C1C=C2C=CC3CC2(O1)C1CCCCN31',
#  'CCN1CC2(C)CCC(O)C34C1C(CC23)C12CC(=C(C)C1O)C(=O)CC24',
#  'O=c1cc(-c2ccccc2O)oc2ccc(O)cc12',
#  'O=Cc1ccc(O)cc1',
#  'O=c1cc(-c2ccc3c(c2)OCCO3)oc2ccc(F)cc12',
#  'COc1ccccc1-n1c(O)cc(Sc2ccccc2C(=O)O)c1O',
#  'O=C(CCSc1nnnn1-c1ccccc1)Nc1ccc(F)cc1',
#  'CCOC(=O)c1c[nH]c2ccc(Cl)cc2c1=O',
#  'CCOC(=O)c1c(NC(=O)COc2ccc(-c3ccccc3)cc2)sc(C)c1C',
#  'Cc1nnc(NC(=O)COc2ccc3ccccc3c2)s1',
#  'CCOC(=O)c1c[nH]c2ccc(CC)cc2c1=O',
#  'O=C(NCc1nc2ccccc2[nH]1)c1ccccc1',
#  'CC1(C)CC(=O)c2c(nc3c(c2-c2cccc([N+](=O)[O-])c2)C(=O)CC(C)(C)C3)C1',
#  'O=C(CC1Sc2ccccc2NC1=O)Nc1ccc(F)cc1',
#  'CCOC(=O)c1c(C)oc2ccc(NS(=O)(=O)c3cc([N+](=O)[O-])ccc3Cl)cc12',
#  'CCOC(=O)c1c(C)oc2ccc(NS(=O)(=O)c3ccc4ccccc4c3)cc12',
#  'CC(=O)c1c(C)oc2ccc(NS(=O)(=O)c3c(C)cc(C)cc3C)cc12',
#  'O=C(OCCN1C(=O)c2ccccc2C1=O)c1ccccc1C(=O)c1ccc(Cl)cc1',
#  'Cc1ccc(NC(=O)CCN2C(=O)c3cccc4cccc(c34)C2=O)cc1',
#  'Brc1c(CSc2nc3ccccc3o2)nc2ncccn12',
#  'O=c1cc(-c2ccc3c(c2)OCCO3)oc2ccc(Cl)cc12',
#  'O=c1cc(-c2cc(Br)cc3c2OCOC3)oc2ccc(Cl)cc12',
#  'O=c1cc(-c2cc(Cl)cc3c2OCOC3)oc2ccc(F)cc12',
#  'O=C(CN1C(=O)c2ccccc2C1=O)Nc1nc(-c2ccccc2)cs1',
#  'O=C1c2cccc3cccc(c23)N1CSc1nc2ccccc2s1',
#  'S=c1[nH]nc(-c2ccncc2)n1-c1ccccc1',
#  'Cc1cc2nnc(SCc3ccccc3[N+](=O)[O-])n2c2ccccc12',
#  'O=C(CSc1nnnn1-c1ccccc1)Nc1cccc([N+](=O)[O-])c1',
#  'O=C1c2ccccc2C(=O)N1c1ncc(Cc2ccc(Br)cc2)s1',
#  'O=C(Nc1ccc(S(=O)(=O)Nc2nccs2)cc1)c1ccc(Br)s1',
#  'Cc1ccc(S(=O)(=O)N2CCN(S(=O)(=O)c3ccc(C)c(C)c3C)C(C)C2)c(C)c1C',
#  'Cn1c(=O)n(C)c2cc(S(=O)(=O)Nc3cc(C(F)(F)F)ccc3Cl)ccc21',
#  'Cc1ccccc1NC(=O)CSc1nnnn1-c1c(C)cccc1C',
#  'Cc1ccc(C)c(-n2nnnc2SCC(=O)NC(c2nc3ccccc3[nH]2)C(C)C)c1',
#  'Cc1ccccc1-n1nnnc1SCC(=O)N(C)Cc1cc(=O)[nH]c2ccccc12',
#  'Cc1ccc2oc(C(=O)Nc3ncc(Cc4ccccc4)s3)cc(=O)c2c1',
#  'COc1ccccc1NC(=O)CCSc1nnnn1-c1cccc(C)c1C',
#  'Cc1ccccc1-c1nnn(CC(=O)Nc2c(C)cccc2C)n1',
#  'CCc1ccccc1NC(=O)Cn1nnc(-c2ccccc2C)n1',
#  'Nc1c(-c2nc(-c3ccccc3)no2)nnn1-c1ccc(C(F)(F)F)c(Cl)c1',
#  'CC(C)c1ccc(-n2nnc(-c3nc(-c4ccccc4Cl)no3)c2N)cc1',
#  'Cc1ccccc1-c1noc(-c2nnn(-c3ccc(F)c(Cl)c3)c2C)n1',
#  'Cc1ccccc1-c1noc(-c2nnn(-c3cccc(C(F)(F)F)c3)c2C)n1',
#  'Cc1c(-c2nc(-c3ccccc3Cl)no2)nnn1-c1ccc(F)cc1',
#  'O=C(O)Cc1cnnn1-c1cccc(C(F)(F)F)c1',
#  'O=C(O)Cc1cnnn1-c1ccc(Cl)cc1Cl',
#  'Nc1ccc2oc(-c3ccccc3)cc(=O)c2c1',
#  'CC(C(=O)N1CCN(Cc2ccccc2)CC1)n1nnc2ccccc2c1=O',
#  'COc1ccccc1-c1cc(=O)c2cc(Br)ccc2o1',
#  'COc1ccc2c(=O)cc(-c3ccc(Cl)cc3Cl)oc2c1',
#  'CCOC(=O)c1ccccc1NCc1cc(=O)oc2cc(C)c(O)cc12',
#  'O=c1c2ccccc2oc2cc(OCc3c(F)cccc3F)cc(O)c12',
#  'Cc1coc2cc3oc(=O)c(CCC(=O)NC(C(=O)O)c4ccccc4)c(C)c3cc12',
#  'CC(C)C(NC(=O)c1ccc(OCc2ccc(Cl)cc2)cc1)c1nc(-c2nc[nH]n2)no1',
#  'COC(=O)c1nc(NC(=O)CCCc2nnc3ccccn23)sc1Cc1ccccc1',
#  'CC(C)C(NC(=O)C1CC(=O)N(c2[nH]nc3cccc(F)c23)C1)c1nc2ccccc2[nH]1',
#  'O=C(NCCCc1nc2ccccc2[nH]1)c1c[nH]c2c(Cl)cccc2c1=O',
#  'CC(C)n1c(CCCNC(=O)c2c[nH]c3c(F)cccc3c2=O)nc2ccccc21',
#  'Cn1c(CCCCCNC(=O)c2c[nH]c3c(F)cccc3c2=O)nc2ccccc21',
#  'O=C1CCc2ccc(OCC(=O)NC(Cc3c[nH]c4ccccc34)C(=O)O)cc2N1',
#  'Cn1nnc(-c2cccc(NC(=O)Cn3cnc4ccsc4c3=O)c2)n1',
#  'COc1ccc2cnn(CC(=O)NC(c3nc4ccccc4n3C)C(C)C)c(=O)c2c1OC',
#  'Cc1nnnn1-c1ccccc1C(=O)N1CCC(c2nc3ccccc3[nH]2)CC1',
#  'CC(C)C(NC(=O)C1CC(=O)N(c2[nH]nc3ccccc23)C1)c1nc2ccccc2n1C',
#  'Cc1[nH]nc(-c2ccc(Cl)cc2)c1CC(=O)NC(CO)Cc1ccccc1',
#  'c1ccc(OCc2nc3nccc(-c4cccnc4)n3n2)cc1',
#  'c1ccc(OCc2nc3nccc(-c4ccncc4)n3n2)cc1',
#  'O=C(O)C(Cc1c[nH]c2ccccc12)c1ccccc1',
#  'COc1cc(-c2cc(=O)c3cc(Cl)ccc3o2)ccc1O',
#  'COc1cc(-c2cc(=O)c3cc(Br)ccc3o2)ccc1O',
#  'COc1ccc(S(=O)(=O)NCCc2c[nH]c3ccc(F)cc23)cc1',
#  'O=C(CCCn1c(=O)[nH]c2ccccc2c1=O)NCc1ccncc1',
#  'CC(=O)c1ccccc1C(=O)NCCc1c[nH]c2ccc(F)cc12',
#  'O=C(NCCc1c[nH]c2ccccc12)c1cc(=O)[nH]c2ccccc12',
#  'COc1cc(NC(=O)c2ccccc2-n2cnnn2)cc(OC)c1',
#  'O=C1c2cccc3cccc(c23)C(=O)N1Cc1nnc(Nc2ccccc2)s1',
#  'Cc1ccc(OCC(O)Cn2c(N3CCOCC3)nc3c2c(=O)[nH]c(=O)n3C)cc1C',
#  'COCCCn1c(C(=O)NCc2ccco2)cc2c(=O)n(C)c(=O)n(C)c21',
#  'COc1ccc(C2c3c(-c4cc(C)ccc4O)n[nH]c3C(=O)N2CCCOC(C)C)cc1',
#  'Cc1cccc(CSc2nnc(NC(=O)c3cc(-c4cccs4)on3)s2)c1',
#  'Cc1ccc(CSc2nnc(NC(=O)c3cc(-c4cccs4)on3)s2)cc1',
#  'O=C(COc1ccc(-n2cnnn2)cc1)Nc1nc2ccc(F)cc2s1',
#  'Cc1cc(C)c2nc(NC(=O)COc3ccc(-n4cnnn4)cc3)sc2c1',
#  'CCC(CC)C(=O)Nc1nonc1-c1ccc2c(c1)CCCC2',
#  'Cc1nonc1COc1ccc(C(=O)Nc2nnc(SCc3cccc4ccccc34)s2)cc1',
#  'Cc1c(C(=O)N2CCC(c3nc4ccccc4[nH]3)CC2)oc2ccc(Cl)cc12',
#  'CN(Cc1ccccc1)c1nn2cnnc2c2ccccc12',
#  'Cc1c(C(=O)N2CCC(c3nc4ccccc4[nH]3)CC2)oc2ccccc12',
#  'COC(=O)c1c(NC(=O)c2cc(=O)c3c(C)cc(C)cc3o2)sc2c1CCC2',
#  'CCOc1ccc(-c2nsc(NC(=O)c3ccccc3)n2)cc1OC',
#  'O=C(NCc1csc(-c2ccccc2)n1)c1ccccc1[N+](=O)[O-]',
#  'CC(C)(CNC(=O)c1cc(-c2ccc(Br)cc2)on1)N1CCOCC1',
#  'Cc1cc2oc(C(O)=NCC(c3ccco3)N3CCCC3)cc(=O)c2cc1Cl.Cl',
#  'COc1cc2c(cc1OC)C(c1ccccc1[N+](=O)[O-])=NCC2',
#  'N#CCC(=O)c1c[nH]c2ccccc12',
#  'Cc1ccccc1Nc1nc(Nc2ccccc2)nc2c1cnn2C',
#  'CCc1ccc(C2C(C(=O)c3ccc(OC)cc3C)C(=O)C(=O)N2CCCN(C)C)cc1',
#  'Cc1ccc2occ(C=NNc3oc(C)nc3C#N)c(=O)c2c1',
#  'CCNC(=O)c1c(NC(=O)C(C)Oc2ccccc2OC)sc2c1CCCC2',
#  'COCCCn1c(=N)c(C(=O)NC(C)c2ccccc2)cc2c(=O)n3ccccc3nc21',
#  'C=CCOC(=O)C1=C(C)N=C2SCCC(=O)N2C1c1ccc(OCCCC)c(OCC)c1',
#  'Cc1ccc(C)c(C(=O)C2C(=O)C(=O)N(c3nnc(C)s3)C2c2ccc(C(C)C)cc2)c1',
#  'Cc1cc2oc(C(=O)Nc3nnc(C(C)C)s3)c(C)c2cc1C',
#  'C=CCSc1nnc(NC(=O)c2oc3c(C)c(C)ccc3c2C)s1',
#  'C=CCSc1nnc(NC(=O)c2cccc(OC)c2)s1',
#  'CCCSc1ncc(Cl)c(C(=O)Nc2sc3c(c2C(=O)OC)CCC3)n1',
#  'CCSc1ncc(Cl)c(C(=O)Nc2nnc(SCc3ccc(C)cc3)s2)n1',
#  'COCCCN1C(=O)c2oc3ccccc3c(=O)c2C1c1ccccc1F',
#  'COC(=O)c1c(NC(=O)Cc2coc3ccc(C)cc23)sc2c1CCC2',
#  'COc1ccc(NC(=O)c2oc3ccccc3c2NC(=O)Cc2coc3ccc(C)cc23)cc1',
#  'O=C1c2[nH]nc(-c3ccccc3O)c2C(c2ccc(Br)cc2)N1CC1CCCO1',
#  'C=CCSc1nnc(NC(=O)Cc2coc3ccc(CC)cc23)s1',
#  'COCCNC(=O)c1c(NC(=O)Cc2coc3cc(C)cc(C)c23)sc2c1CCCC2',
#  'O=C(Nc1cccc(C(F)(F)F)c1)c1cc(=O)c2cc(Cl)ccc2o1',
#  'CCCSc1nnc(NC(=O)c2nc(S(C)(=O)=O)ncc2Cl)s1',
#  'CCCS(=O)(=O)c1ncc(Cl)c(C(=O)Nc2ccccc2C(=O)OC)n1',
#  'Cc1cc(C)c2nc(N3C(=O)C(=O)C(C(=O)c4ccncc4)C3c3ccc(F)cc3)sc2c1',
#  'Cc1ccc2c(CC(=O)Nc3sc4c(c3C(=O)NCc3ccco3)CCC4)coc2c1',
#  'CCOCCCNC(=O)c1c(NC(=O)Cc2coc3ccc(CC)cc23)sc2c1CCC2',
#  'CCc1nonc1NC(=O)COc1ccc(Cl)c(C)c1',
#  'O=C(c1c[nH]c2ccccc12)C1CCNCC1',
#  'O=C(c1c[nH]c2ccccc12)C1CCCNC1',
#  'CC(=O)c1ccc(OCCOc2ccc(C(C)=O)cc2)cc1',
#  'c1ccc(-c2ccc3[nH]cc(C4CCNCC4)c3c2)cc1',
#  'Cc1ccc2c(=O)cc(C(O)=NCC(c3ccco3)N3CCCC3)oc2c1.Cl',
#  'Cc1ccc2c(C)c(C(=O)NCC(c3cccs3)N3CCOCC3)oc2c1C',
#  'COc1ccc(Cn2nccc2NC(=O)c2cc(=O)c3cc(C)c(C)cc3o2)cc1',
#  'CCc1ccc2oc(C(=O)NCCc3nc(-c4ccccc4)no3)c(C)c2c1',
#  'Cc1ccc(-c2noc(C3CCN(S(=O)(=O)c4ccccc4)CC3)n2)cc1',
#  'CN(Cc1ccccc1)c1oc(-c2ccccc2[N+](=O)[O-])nc1C#N',
#  'COc1ccc(NC(=O)c2c(C)noc2-c2ccc(Cl)cc2)cc1Cl',
#  'Cc1nc(C)c(-c2nnc(NC(=O)COc3c(C)cccc3C)o2)s1',
#  'Cc1nc(C)c(-c2nnc(NC(=O)COc3ccccc3C)o2)s1',
#  'COC(=O)CNC(=O)c1nc(SCc2ccc(C)cc2)ncc1Cl',
#  'COC(=O)C(CC(C)C)NC(=O)CCc1nc(-c2ccc(Cl)cc2)no1',
#  'Cc1cccc(OCCNC(=O)c2cc(-c3ccc(F)c(F)c3)on2)c1C',
#  'COc1ccccc1OCCNC(=O)c1ccc(F)cc1',
#  'COc1ccccc1OCCNC(=O)C(C)Oc1cccc(C)c1C',
#  'COc1ccc2oc(C)c(C(=O)Nc3nc4ccc(C)cc4s3)c2c1',
#  'O=c1cc(-c2ccc3c(c2)OCCO3)oc2ccc(Br)cc12',
#  'Brc1ccc(-c2cc[nH]n2)s1',
#  'Clc1ccc2nnc(-c3ccccc3)n2n1',
#  'COc1cccc(F)c1-c1nc(C)c(C(=O)Nc2nc3ccccc3s2)s1',
#  'O=C(NCCc1c[nH]c2ccccc12)c1cc(-c2cccnc2)nc2ccccc12',
#  'COc1ccccc1C(=O)NCCNC(=O)c1c[nH]c2ccccc12',
#  'O=C(Cc1csc(-c2c(Cl)cccc2Cl)n1)NC(C(=O)O)c1ccccc1',
#  'O=C(Cn1ccc2ccc(F)cc21)NC(C(=O)O)c1ccccc1',
#  'COc1ccc(OC)c(N2CC(C(=O)Nc3nccs3)CC2=O)c1',
#  'CC(=O)Nc1ccc(S(=O)(=O)N2CCN(C(=O)c3cc(C)nc4ccccc34)CC2)cc1',
#  'COc1ccc2c(ccn2CC(=O)NC(C(=O)O)c2ccccc2)c1',
#  'COc1ccc2[nH]cc(C(=O)CC#N)c2c1',
#  'N#Cc1cccc(-c2nc3ncccc3o2)c1',
#  'COc1nc(-c2cccs2)cc(-c2ccc(C)cc2)c1C#N',
#  'c1ccc2c(OCc3nn4c(-c5ccncc5)nnc4s3)cccc2c1',
#  'O=c1c(=Cc2cccs2)sc2nc(C3COc4ccccc4O3)nn12',
#  'CC(C)n1c(=N)c(C(=O)NCc2ccc(F)cc2)cc2c(=O)n3ccccc3nc21',
#  'COC(=O)c1n[nH]c2ccccc2c1=O',
#  'COc1ccc2nc(C)cc(NCCSc3cc(C)nc4ccc(OC)cc34)c2c1',
#  'CC1C2=C(CC(C)(C)CC2=O)OC2=C1C(=O)CC(C)(C)C2',
#  'c1ccc(Cn2c(-c3ccncc3)nc3cccnc32)cc1',
#  'Cc1sc2nc(CCCN3C(=O)c4cccc5cccc(c45)C3=O)n(CCO)c(=O)c2c1C',
#  'CCOC(=O)c1ccc(CNC(=O)CSc2nc(=O)c3c(C)c(C(=O)O)sc3[nH]2)cc1',
#  'CCOC(=O)c1c(NC(=O)CSc2nnc(Cc3csc(N)n3)n2C)sc(C)c1C',
#  'CCOC(=O)c1c(NC(=O)CSc2nc(N)c3c(C)c(C)sc3n2)sc(C)c1C',
#  'Cc1ccc(-c2nc(C(=O)Nc3ncnc4[nH]cnc34)c(-n3nc(C)cc3C)o2)cc1',
#  'Cc1cc(C)c(O)c(-c2cc(C(=O)Nc3ccccc3)no2)c1',
#  'Cc1ccc(C)c(NC(=O)CNC(=O)Cc2coc3cc(C)c(C)cc23)c1',
#  'Cc1ccc(NC(=O)CNC(=O)Cc2coc3cc(C)c(C)cc23)c(C)c1',
#  'COC(=O)CCNC(=O)CNC(=O)Cc1coc2cc(C)c(C)cc12',
#  'CC(C)C(NC(=O)Cc1c[nH]c2ccccc12)c1nnc2ccccn12',
#  'O=C(Cc1csc(-c2cccc(Cl)c2)n1)NCc1cccc(C(=O)O)c1',
#  'Cc1cc(C(=O)NCCc2c[nH]c3ccccc23)c2c(C)noc2n1',
#  'CN(Cc1ccccc1)c1ccc2nnc(C(F)(F)F)n2n1',
#  'COc1cc2ncn(CCC(=O)Nc3ccccn3)c(=O)c2cc1OC',
#  'CC(=O)Nc1cccc(NC(=O)c2cc(C)nc3onc(C)c23)c1',
#  'O=C(Cc1csc(-c2ccccc2F)n1)NCc1cccc(C(=O)O)c1',
#  'CC(=O)c1ccc(NC(=O)c2snnc2-c2ccccc2)cc1',
#  'O=C(c1c(-n2cccc2)sc2c1CCC2)N1CCC(O)(c2ccc(Cl)cc2)CC1',
#  'Cc1nnc(NC(=O)Cc2c(C)c3cc4c(C)coc4c(C)c3oc2=O)s1',
#  'Cc1coc2c(C)c3oc(=O)c(CC(=O)Nc4nnc(C(C)C)s4)c(C)c3cc12',
#  'COc1ccccc1CNC(=O)CCSc1ncnc2sc(C)c(C)c12',
#  'Cc1sc2ncnc(SCCC(=O)N3CCN(c4ccccn4)CC3)c2c1C',
#  'CCCCc1ccc(NC(=O)Cn2nc(-c3ccc(F)cc3OC)ccc2=O)cc1',
#  'Cn1cc(C(=O)NCCNC(=O)Cc2c[nH]c3ccccc23)c2ccccc21',
#  'COc1ccc2[nH]cc(C(=O)N(C)c3ccccc3)c(=O)c2c1',
#  'O=C(Cn1nc(-c2cccc3ccccc23)ccc1=O)NC(Cc1ccccc1)C(=O)O',
#  'CC(=O)Nc1cccc(NC(=O)c2cnn(C)c2-n2cccc2)c1',
#  'Cn1ncc(C(=O)NCc2cccc(F)c2)c1-n1cccc1',
#  'Cc1csc2ncc(C(=O)Nc3ccc4cc[nH]c4c3)c(=O)n12',
#  'CC(=O)Nc1cccc(NC(=O)c2cnc3sccn3c2=O)c1',
#  'Cc1nn(C)c2nc(C(C)C)cc(C(=O)NCCc3c[nH]c4ccccc34)c12',
#  'Cc1cc(C)n(-c2ccc3nnc(CCC(=O)NC4CCCCCCC4)n3n2)n1',
#  'O=C(NCc1cccnc1)C1CCN(c2ccc3nnc(-c4ccccc4)n3n2)CC1',
#  'COc1ccc2cnn(CC(=O)NCCn3cnc4ccccc43)c(=O)c2c1OC',
#  'Cc1csc(NC(=O)CCC(=O)Nc2ccc(Br)cc2)n1',
#  'O=C(NCCn1c(=O)c(=O)[nH]c2ccccc21)c1[nH]nc2ccccc12',
#  'CN1C(=O)c2cccc3c(S(=O)(=O)NNC(=O)c4ccc(O)cc4)ccc1c23',
#  'CCCCN(c1ccccc1C(=O)O)S(=O)(=O)c1ccc(OC)c2ccccc12',
#  'CCCN1C(=O)c2cccc3c(S(=O)(=O)Nc4cccc(C(=O)O)c4)ccc1c23',
#  'Cc1ccccc1-n1nnc(C(=O)NCc2ccccn2)c1C',
#  'Cc1ccc(-n2nnc(-c3nnc(-c4ccccc4)o3)c2C2CC2)cc1',
#  'Cc1oc(-c2ccc(Cl)cc2)cc1-c1nnc(-c2ccccn2)o1',
#  'Cc1oc(-c2ccc(Cl)cc2)cc1-c1nnc(-c2cccnc2)o1',
#  'Brc1ccc(-c2ccc(-c3nnc(-c4ccncc4)o3)o2)cc1',
#  'COCc1c(-c2nnc(Cc3ccc(Cl)cc3)o2)nnn1-c1ccc(F)cc1',
#  'COCc1c(-c2nnc(-c3cccnc3)o2)nnn1-c1cccc(C(F)(F)F)c1',
#  'c1ccc(-c2noc(CSc3nnnn3-c3ccccc3)n2)cc1',
#  'COc1cccc2cc(C(=O)NCCc3nc(-c4ccc(Cl)cc4)no3)oc12',
#  'O=c1cc(-c2cccc(F)c2)oc2cc(O)ccc12',
#  'O=C(Cc1n[nH]c(=O)c2ccccc12)NC1CCN(Cc2ccccc2)CC1',
#  'COc1ccc(NC(C)=O)cc1NC(=O)Cc1n[nH]c(=O)c2ccccc12',
#  'O=C(Cc1n[nH]c(=O)c2ccccc12)Nc1nc(-c2cccs2)cs1',
#  'COc1cccc(C2C(C(=O)Nc3nc4ccc(C)cc4s3)CC(=O)N2C)c1OC',
#  'CCOC(=O)Cc1csc(NC(=O)c2cn(CCC(C)C)c(=O)c3ccccc23)n1',
#  'Cc1nn(C)c(C)c1-c1cc(C(=O)NCc2nnc3ccccn23)[nH]n1',
#  'Cc1nn(C)c(C)c1-c1cc(C(=O)NCCSc2ccccc2)[nH]n1',
#  'O=C(NCCc1nc2ccccc2[nH]1)C(c1ccccc1)n1cnnn1',
#  'c1cc(-c2ccnc3nc(C4CCC4)nn23)ccn1',
#  'c1cc(-c2ccsc2)n2nc(C3CCC3)nc2n1',
#  'O=C(NCCCc1nnc2ccccn12)c1cc2ccc(Cl)cc2s1',
#  'COc1ccc(-c2cc(C(=O)NCc3nc4ccccc4n3C)[nH]n2)cc1OC',
#  'COc1cccc(-c2ccnc3nc(-c4ccccc4OC)nn23)c1',
#  'c1coc(-c2nc3nccc(-c4cc5ccccc5o4)n3n2)c1',
#  'COc1ccc(-c2ccnc3nc(Cc4cc(F)cc(F)c4)nn23)c(F)c1',
#  'Fc1cc(F)cc(Cc2nc3nccc(-c4cc5ccccc5o4)n3n2)c1',
#  'Cc1ccc(C(=O)NCc2nc3ccccc3[nH]2)c(-n2cnnn2)c1C',
#  'COc1cccc(-c2ccnc3nc(-c4cccs4)nn23)c1',
#  'c1cc(-c2ccsc2)n2ncnc2n1',
#  'COc1ccccc1CNC(=O)C1CC(=O)N(c2[nH]nc3cccc(F)c23)C1',
#  'COc1ccc(-c2[nH]nc(C)c2CC(=O)NCc2ccncc2)cc1',
#  'Cc1nnc(NC(=O)C2CC(=O)N(c3[nH]nc4cccc(F)c34)C2)s1',
#  'O=C(c1c[nH]c2ccccc12)C1CCCN(C(=O)OCc2ccccc2)C1',
#  'N#Cc1nc(-c2ccccc2)oc1S(=O)(=O)n1ncnc1N',
#  'COc1cc(C(c2c(O)cc(C)oc2=O)c2c(O)cc(C)oc2=O)ccc1O',
#  'CCCCNc1nc(Nc2ccccc2)c2cnn(C)c2n1',
#  'Cc1ccc(-n2ncc3c2ncn2c(CCc4ccccc4)nnc32)cc1C',
#  'COc1ccc(-c2nnc3c4cnn(-c5ccc(C)c(C)c5)c4ncn23)cc1',
#  'CCc1ccc(-c2nnc3c4cnn(-c5ccccc5)c4ncn23)cc1',
#  'COc1ccc(-c2nnc3c4cnn(-c5cc(C)cc(C)c5)c4ncn23)cc1',
#  'Clc1ccc(-n2ncc3c2ncn2c(C4CCCCC4)nnc32)cc1',
#  'Clc1ccc(-n2ncc3c2ncn2c(Cc4cccc5ccccc45)nnc32)cc1',
#  'Cc1nnc2c3cnn(-c4ccc(Cl)cc4)c3ncn12',
#  'COc1ccc(-c2nnc3c4cnn(-c5ccc(Cl)cc5)c4ncn23)cc1',
#  'Clc1ccc(-c2nnc3c4cnn(-c5ccc(Cl)cc5)c4ncn23)cc1',
#  'CCc1ccc(-c2nnc3c4cnn(-c5ccc(Cl)cc5)c4ncn23)cc1',
#  'Fc1ccc(-n2ncc3c2ncn2c(C4CCCCC4)nnc32)cc1',
#  'Fc1ccc(-n2ncc3c2ncn2c(CCc4ccccc4)nnc32)cc1',
#  'CC(C)(C)c1ccc(-c2nnc3c4cnn(-c5ccc(F)cc5)c4ncn23)cc1',
#  'COc1ccc(-c2nnc3c4cnn(-c5ccc(F)cc5)c4ncn23)cc1',
#  'Cc1cccc(-c2nnc3c4cnn(-c5ccc(C)cc5C)c4ncn23)c1',
#  'COc1ccc(-c2nnc3c4cnn(-c5ccccc5C)c4ncn23)cc1',
#  'Cc1cccc(-c2nnc3c4cnn(-c5ccccc5C)c4ncn23)c1',
#  'COc1ccc(-c2nnc3c4cnn(-c5ccccc5C)c4ncn23)cc1OC',
#  'CCc1ccc(-c2nnc3c4cnn(-c5cccc(C)c5)c4ncn23)cc1',
#  'CC(C)(C)c1ccc(-c2nnc3c4cnn(-c5ccccc5)c4ncn23)cc1',
#  'COc1ccc(-c2nnc3c4cnn(-c5ccccc5)c4ncn23)cc1OC',
#  'O=C1C(=O)N(c2nncs2)C(c2ccc(Cl)cc2)C1C(=O)c1cccs1',
#  'Cc1ccc(C(=O)C2C(=O)C(=O)N(c3ccccn3)C2c2ccc(C)cc2)cc1',
#  'Cn1c(=O)c2cc(C(=O)NCC(=O)c3ccccc3)n(Cc3ccccc3)c2n(C)c1=O',
#  'c1ccc(Oc2ncnc3ccccc23)cc1',
#  'Clc1ccc(Oc2ncnc3ccccc23)cc1',
#  'C=CCN(CC=C)Cc1c[nH]c2ccccc12',
#  'CN1CCN(Cc2c[nH]c3ccccc23)CC1',
#  'Cc1cc2nnc(SCCCCN3C(=O)c4ccccc4C3=O)n2c2ccccc12',
#  'Cc1ccc(-n2c(N)c(C#N)c3nc4ccccc4nc32)c(C)c1',
#  'Cc1ccc(-n2c(N)c(C#N)c3nc4ccccc4nc32)cc1C',
#  'Cc1ccc(-n2c(N)c(C#N)c3nc4ccccc4nc32)c(Br)c1',
#  'Cc1ccc(-n2c(N)c(C#N)c3nc4ccccc4nc32)cc1Cl',
#  'Cc1ccc(C)c(OCC(=O)Nc2nnc(Cc3ccc(Cl)cc3)s2)c1C',
#  'Cc1cc(Cl)ccc1OC(C)C(=O)Nc1nc2ccc([N+](=O)[O-])cc2s1',
#  'Cc1ccc2[nH]c(SCc3cn4cccnc4n3)nc2c1',
#  'CCCCOC(=O)Cn1cnc2scc(-c3ccc(C)c(C)c3)c2c1=O',
#  'CCCCOC(=O)CSc1ncnc2sc(C)c(C)c12',
#  'COc1cc(C(=O)OCC(=O)Nc2ccc(C)cc2)c(Br)c(OC)c1OC',
#  'COc1cccc(C(=O)OCC(=O)NCc2ccccc2)c1',
#  'Cc1ccc(C(=O)OCC(=O)Nc2cccc(Cl)c2C)cc1C',
#  'CCOC(=O)c1sc(NC(=O)Cn2cnc3sc(C)c(C)c3c2=O)c(C(=O)OCC)c1C',
#  'COc1ccc(-c2cc(=O)c3cc(OCc4ccccc4)ccc3o2)cc1',
#  'CCOC(=O)c1sc2ncn3c(CCc4ccccc4)nnc3c2c1C',
#  'CCOC(=O)c1sc2ncn3c(-c4ccccc4)nnc3c2c1C',
#  'COC(=O)c1cccc(Nc2ncnc3ccc([N+](=O)[O-])cc23)c1',
#  'CCOc1ccc(NC(=O)COC(=O)CCc2ccccc2)cc1',
#  'O=C(O)c1ccccc1-c1cc(=O)c2cc(Cl)ccc2o1',
#  'CCOc1ccc(NC(=O)CSCc2ccc([N+](=O)[O-])cc2)cc1',
#  'COc1ccc(-c2csc3ncn(CC(=O)Nc4sc5c(c4C#N)CCC5)c(=O)c23)cc1OC',
#  'COC(=O)C(C)n1cnc2sc(C)c(-c3ccc(C)c(C)c3)c2c1=O',
#  'Cc1[nH]c2c(C)c(Cl)ccc2c(=O)c1CN1CCCC(C)C1',
#  'N#Cc1c(NC(=O)Cn2nnc3sc4c(c3c2=O)CCCC4)sc2c1CCC2',
#  'Cc1cc(C)c2oc(-c3cccc(Br)c3)cc(=O)c2c1',
#  'O=c1cc(-c2ccc(Cl)cc2)oc2ccc(O)cc12',
#  'O=c1cc(-c2cccc(Br)c2)oc2ccc(O)cc12',
#  'O=c1cc(-c2ccccc2)oc2ccc(O)cc12',
#  'CCOC(=O)C(C(C)=O)C1=NC(=NC(=O)c2ccccc2[N+](=O)[O-])c2ccccc21',
#  'CC(=O)C(C(=O)OC(C)(C)C)C1=NC(=NC(=O)c2ccccc2[N+](=O)[O-])c2ccccc21',
#  'C=CCOc1ccc2oc(-c3ccc(Cl)cc3)cc(=O)c2c1',
#  'Fc1ccccc1CSc1nnc2c(n1)[nH]c1ccccc12',
#  'CCCCc1ccc2[nH]cc(C(=O)OCC)c(=O)c2c1',
#  'Cc1cc(C)nc(Oc2ccc(NC(=O)c3ccccc3C(=O)O)cc2)n1',
#  'CC(=O)c1cccc(NC(=O)CSc2nc(=O)c(-c3ccccc3)n[nH]2)c1',
#  'Cc1n[nH]c(=O)nc1SCC(=O)N(C)c1ccccc1',
#  'Cc1cc(SCC(=O)c2c[nH]c3ccccc23)ncn1',
#  'Cc1cc2nnc(SCC(=O)OCCOc3ccccc3)n2c2ccccc12',
#  'Cc1cc2nnc(SCC(=O)NCCc3ccccc3)n2c2c(C)cccc12',
#  'Cc1cc2nnc(SCC(=O)Nc3c(C)n(C)n(-c4ccccc4)c3=O)n2c2c(C)cccc12',
#  'COc1cccc2c(C)cc3nnc(SCC(=O)c4ccc(F)cc4)n3c12',
#  'Cc1cc(C)c2nc(NC(=O)c3sc(C)nc3C)sc2c1',
#  'Cc1nc(-c2ccccc2)sc1C(=O)Nc1nc2c(C)cccc2s1',
#  'COc1ccc(Nc2c(C(=O)O)cnc3ccc(C(=O)O)cc23)cc1.Cl',
#  'O=C1CN(Cc2ccc3c(c2)OCO3)C2CS(=O)(=O)CC2N1c1ccccc1',
#  'COc1cc(C(=O)Nc2nc(-c3ccc4c(c3)NC(=O)C(C)O4)c(C)s2)cc(OC)c1OC',
#  'CCCNC1CS(=O)(=O)CC1S(=O)(=O)c1ccc(F)c(C)c1',
#  'COc1cc(C)c(C)cc1S(=O)(=O)NCC(c1cccnc1)S(=O)(=O)c1ccc(F)c(C)c1',
#  'COc1cc2ncnc(NCCc3c[nH]c4ccccc34)c2cc1OC',
#  'CCOC(=O)c1cc(-c2cccc([N+](=O)[O-])c2)[nH]c1N',
#  'Cc1cc(NC(=O)C(Cc2ccccc2)NC(=O)c2ccc(F)c(F)c2F)no1',
#  'O=C(NCc1ccc2c(c1)OCO2)c1cc(N2CCCCS2(=O)=O)ccc1Cl',
#  'Cc1cc(OCC(=O)N2CCC(c3nc4ccccc4o3)CC2)cc(C)c1Cl',
#  'c1ccc2c(c1)ccc1nnc(SCc3nc4ccccc4[nH]3)n12',
#  'Cc1cc2c(NCCc3c[nH]c4ccccc34)ncnc2s1',
#  'NC(Cc1c[nH]c2ccccc12)CN1CCCC1',
#  'NC(Cc1c[nH]c2ccccc12)CN1CCCCC1',
#  'CCOC(=O)c1sc(NC(=O)CSc2nnc3ccc4ccccc4n23)nc1C',
#  'Brc1c(CSc2nncn2-c2ccccc2)nc2ncccn12',
#  'Cc1cccc2nc(CSc3nncn3-c3ccccc3)c(Br)n12',
#  'OC(COc1ccccc1)Cn1cnc2ccccc21',
#  'COC(=O)CSc1n[nH]c(-c2ccncc2)n1',
#  'Cc1sc2[nH]c(SCC(=O)c3ccc(F)cc3)nc(=O)c2c1C',
#  'Cc1sc(-c2ccc(O)cc2)nc1-c1c[nH]c2ccccc12',
#  'O=C(CSc1n[nH]c(-c2ccncc2)n1)c1c[nH]c2ccccc12',
#  'Cc1cc(C)c2c(=O)[nH]c(SCC(=O)c3c[nH]c4ccccc34)nc2n1',
#  'O=C(O)c1ccccc1NC(=O)c1cc2cc(Br)cc(Br)c2oc1=O',
#  'Cc1ccnc(Nc2nc(-c3ccc(F)c(C)c3)cs2)c1',
#  'CC(C)(C)c1ccc(OCC(=O)NNC(=O)c2ccccc2C(=O)O)cc1',
#  'CCN1C(=O)c2cccc3c(S(=O)(=O)NCc4ccccn4)ccc1c23',
#  'COc1cc(OC)cc(C(=O)NCc2ccc3c4c(cccc24)C(=O)N3)c1',
#  'O=C1Nc2ccc(CNS(=O)(=O)c3ccc(Cl)cc3)c3cccc1c23',
#  'CC(=O)c1c(C)oc2ccc(N(C(C)=O)S(=O)(=O)c3cc(C)c(C)cc3C)cc12',
#  'CCCC(=O)N(c1ccc2oc(C)c(C(C)=O)c2c1)S(=O)(=O)c1cc(C)ccc1C',
#  'Cc1c(C(=O)Nc2nnc(CC(C)C)s2)cccc1[N+](=O)[O-]',
#  'CC(C)Cc1nnc(NC(=O)Cc2ccccc2[N+](=O)[O-])s1',
#  'COc1ccc(OC)c(C2C(C(=O)c3ccc(C)o3)C(=O)C(=O)N2c2nc3ccc(F)cc3s2)c1',
#  'CCOc1ccc2nc(N3C(=O)C(=O)C(C(=O)c4ccc(C)o4)C3c3ccccc3OC)sc2c1',
#  'Cc1sc2[nH]c(SCC(=O)NCCc3ccccc3)nc(=O)c2c1C',
#  'Cc1cc(C)n2cc(CSc3nncc(-c4ccccc4)n3)nc2n1',
#  'Cc1ccc([N+](=O)[O-])cc1S(=O)(=O)Nc1cccc(-c2cn3ccccc3n2)c1',
#  'Cc1cc(C)c(S(=O)(=O)Nc2cccc(-c3cn4cccc(C)c4n3)c2)cc1C',
#  'Cc1ccc(S(=O)(=O)Nc2ccc(-c3cn4cccc(C)c4n3)cc2)cc1C',
#  'c1ccc(CSc2nnc3c4ccccc4ncn23)cc1',
#  'CCOc1ccc2nc(NS(=O)(=O)c3ccc4c5c(cccc35)C(=O)N4)sc2c1',
#  'O=C(Nc1ccc(S(=O)(=O)NC2CCCCC2)cc1)c1ccncc1',
#  'O=C1c2cccc3cccc(c23)C(=O)N1CCOCCN1C(=O)c2cccc3cccc(c23)C1=O',
#  'O=C(O)c1ccccc1Sc1cc(O)n(-c2ccc(F)c(Cl)c2)c1O',
#  'FC(F)(F)c1cccc(C=Cc2nn3c(-c4ccccc4)nnc3s2)c1',
#  'C(=Cc1nn2c(-c3ccccc3)nnc2s1)c1cccs1',
#  'c1ccc(-c2nnc(Cn3c4ccccc4c4nc5ccccc5nc43)o2)cc1',
#  'O=C(CSc1nnnn1-c1ccc(Cl)cc1)Nc1nc2ccc(Br)cc2s1',
#  'c1ccc(-c2nnc(COc3ccc4ccccc4c3)o2)cc1',
#  'Cc1ccc(NC(=O)CSc2nnnn2-c2cccc3ccccc23)cc1C',
#  'Cc1ccc(-n2nnnc2SCC(=O)Nc2cc(C)ccc2C)c(C)c1',
#  'CCCSc1nnc(NC(=O)CSc2nnnn2-c2ccccc2F)s1',
#  'CN1C(=O)c2cccc3c(S(=O)(=O)Nc4cccc(C(=O)O)c4)ccc1c23',
#  'COc1ccc(N(C(=O)c2cccnc2)S(=O)(=O)c2ccc3c4c(cccc24)C(=O)N3C)cc1',
#  'CCN1C(=O)c2cccc3c(S(=O)(=O)Nc4cc(OC)ccc4OC)ccc1c23',
#  'CN(c1ccccc1C(=O)O)S(=O)(=O)c1ccc2c3c(cccc13)C(=O)N2',
#  'O=C(COC(=O)c1ccc2ccccc2n1)c1ccc2ccccc2c1',
#  'CCOC(=O)CC(NC(=O)c1cc2ccccc2oc1=O)c1ccccc1Cl',
#  'C=CCn1c(CCCNC(=O)c2ccc(Cl)cc2)nc2ccccc21',
#  'Cc1ccc(C2C(C(=O)c3ccc4c(c3)OCCO4)C(=O)C(=O)N2CCCN(C)C)o1',
#  'Cc1noc(C)c1CSc1nc2c(c(-c3ccccc3)c1C#N)C(=O)CC(C)(C)C2',
#  'O=[N+]([O-])c1ccccc1-c1ccc(-c2nn3c(-c4ccccc4)nnc3s2)o1',
#  'Cc1cc(-c2nn3c(-c4ccccc4)nnc3s2)c2ccccc2n1',
#  'CC(C)C(=O)C(C#N)c1nc(O)c(Cc2ccc(Cl)cc2)s1',
#  'Cc1c(-c2nn3c(-c4ccncc4)nnc3s2)oc2ccccc12',
#  'COc1ccc(CCNC(=O)Cc2c(C)c3cc(Cl)c(O)cc3oc2=O)cc1',
#  'COc1ccc(CCNC(=O)Cc2c(C)c3cc4c(C)c(C)oc4c(C)c3oc2=O)cc1OC',
#  'CCn1c(C2CC(=O)N(c3ccccc3Br)C2)nc2ccccc21',
#  'Clc1ccccc1-c1nnc(COc2ccc3ccccc3c2)o1',
#  'c1ccc2nc3c(nc2c1)c1ccccc1n3Cc1nc2ccccc2o1',
#  'COc1ccc(OC)c(S(=O)(=O)Nc2cccc(-c3cn4cccc(C)c4n3)c2)c1',
#  'c1ccc(CCc2nnc3sc(-c4ccccc4)nn23)cc1',
#  'Brc1cccc(-c2nnc3sc(-c4cccnc4)nn23)c1',
#  'Brc1cccc(-c2nnc3sc(-c4ccncc4)nn23)c1',
#  'Clc1ccc(Cc2nnc3sc(-c4cccnc4)nn23)cc1',
#  'Clc1ccc(Cc2nnc3sc(-c4ccncc4)nn23)cc1',
#  'COc1ccccc1OCc1nnc2sc(-c3ccccc3)nn12',
#  'Clc1ccc(Cc2nnc3sc(-c4ccccc4)nn23)cc1',
#  'Cc1c(-c2nn3c(Cc4ccccc4)nnc3s2)nnn1-c1cccc(C(F)(F)F)c1',
#  'CCc1nnc(NC(=O)c2nnn(-c3ccc4noc(-c5ccccc5)c4c3)c2C)s1',
#  'Cc1cnnn1-c1ccc(NC(=O)c2nnn(-c3ccccc3Cl)c2C)cc1',
#  'Cc1ccc(C)c(-n2nnc(C(=O)Nc3ccc(-n4nncc4C)cc3)c2C)c1',
#  'N#Cc1ccc(-c2nn3c(-c4ccccc4)nnc3s2)cc1',
#  'FC(F)(F)c1ccc(-c2nn3c(-c4ccccc4)nnc3s2)cc1',
#  'Fc1cc(Cl)c(-c2nn3c(-c4ccccc4)nnc3s2)cc1F',
#  'c1ccc(Oc2ccc(-c3nn4c(-c5ccccc5)nnc4s3)cc2)cc1',
#  'Clc1ccc(OCc2nn3c(-c4ccccc4)nnc3s2)c(Cl)c1',
#  'Cc1cc(-c2nn3c(-c4ccccc4)nnc3s2)c2cc(Cl)ccc2n1',
#  'c1ccc(-c2nnc3sc(C4CC4)nn23)cc1',
#  'c1ccc(-c2nn3c(-c4ccccc4)nnc3s2)cc1',
#  'Sc1ccccc1-c1nn2c(-c3ccccc3)nnc2s1',
#  'Clc1cccc(C=Cc2nn3c(-c4ccccc4)nnc3s2)c1',
#  'Cc1c(-c2nnc(-c3ccccc3)o2)nnn1-c1ccc(Br)cc1',
#  'CCSc1nnc(NC(=O)c2cc3cc(C)ccc3o2)s1',
#  'CCc1nnc(NC(=O)Cn2nnc(-c3ccc(C)cc3)n2)s1',
#  'c1ccc(-c2nnc(CSc3nnnn3-c3ccccc3)o2)cc1',
#  'CCc1nnc(NC(=O)c2nnn(-c3ccc4noc(-c5ccc(Cl)cc5)c4c3)c2C)s1',
#  'CSCCC(C(=O)O)n1c(O)c2ccc3c(=O)nc4ccc(c1=O)c2c43',
#  'O=c1cc(-c2ccc(F)cc2)oc2ccc(Cl)cc12',
#  'O=c1cc(-c2ccccc2Cl)oc2ccc(Cl)cc12',
#  'CCOC(=O)c1c[nH]c2ccc(C(F)(F)F)cc2c1=O',
#  'Cc1cc2ncn(CCc3noc(-c4ccccc4)n3)c2cc1C',
#  'COc1ccc(OCCn2c(C3CC(=O)N(c4ccc(F)cc4)C3)nc3ccccc32)cc1',
#  'O=C(NCCCc1nc2ccccc2n1Cc1cccc2ccccc12)c1ccco1',
#  'C=C(C)Cn1c(C2CC(=O)N(Cc3ccc(F)cc3)C2)nc2ccccc21',
#  'CCS(=O)(=O)c1ncc(Cl)c(C(=O)Nc2sc3c(c2C(N)=O)CCCC3)n1',
#  'CCSc1nnc(NC(=O)c2oc3ccc(CC)cc3c2C)s1',
#  'Cc1cc2oc(C(=O)Nc3c(C(=O)Nc4ccccc4)oc4ccccc34)cc(=O)c2cc1C',
#  'COc1cc(CN(CC2CCCO2)C(=O)COc2cc(C)c(Cl)c(C)c2)cc(OC)c1OC',
#  'COC(=O)c1ccccc1NC(=O)c1cc(=O)c2ccc(C)cc2o1',
#  'Cc1ccc2c(=O)cc(C(=O)Nc3sc4c(c3C(=O)NCc3cccnc3)CCCC4)oc2c1',
#  'Cc1ccc2c(=O)cc(C(=O)Nc3c(C(=O)Nc4ccccc4)oc4ccccc34)oc2c1',
#  'COC(=O)c1ccccc1NC(=O)c1cc(=O)c2ccc(C)c(C)c2o1',
#  'COc1cccc(C(=O)N(Cc2ccco2)Cc2ccccc2F)c1',
#  'Cc1cc(C)c2oc(C(=O)Nc3nnc(SCc4ccccc4)s3)cc(=O)c2c1',
#  'Cc1cc(C)c2nc(NC(=O)c3snnc3C)sc2c1',
#  'COC(=O)c1c(NC(=O)c2cc(=O)c3cc(Cl)c(C)cc3o2)sc2c1CCC2',
#  'c1ccc2c(c1)ncn1nc(Cc3c[nH]c4ccccc34)nc21',
#  'Cc1nn2c(SCC(=O)Nc3nccs3)nc3ccccc3c2nc1=O',
#  'COc1ccc2nc(NC(=O)CSc3nc4ccccc4c4nnnn34)sc2c1',
#  'Cn1c(=O)c(CCC(=O)NCc2ccccn2)nc2ccccc21',
#  'COc1ccc2nnc(CCC(=O)Nc3nc4ccccc4[nH]3)n2n1',
#  'COc1ccc2nnc(CCCC(=O)Nc3nncs3)n2n1',
#  'O=C(CCCn1nnc2ccccc2c1=O)NCCn1ccc2ccc(F)cc21',
#  'Cc1nc2ccccc2n(CC(=O)NCCc2c[nH]c3ccc(Cl)cc23)c1=O',
#  'CC(C)Oc1ccc2nnc(CCC(=O)NCCc3c[nH]c4ccccc34)n2n1',
#  'CC(C)Cn1ccc2c(NC(=O)Cc3nn(C(C)C)c(=O)c4ccccc34)cccc21',
#  'Cc1nn(C)c(C)c1CNC(=O)C(C(C)C)N1Cc2ccccc2C1=O',
#  'COCCn1ccc2c(NC(=O)c3ccc(Cl)cc3-n3cnnn3)cccc21',
#  'Cc1ccc(NC(=O)C2CC(=O)N(c3[nH]nc4cccc(F)c34)C2)cc1C',
#  'O=C(Nc1nc2ccccc2s1)C1CC(=O)N(c2[nH]nc3cccc(F)c23)C1',
#  'O=C(NCCCc1nnc2ccccn12)C1CC(=O)N(c2[nH]nc3ccccc23)C1',
#  'C=CCSc1nnc(NC(=O)Cc2coc3ccc(OC)cc23)s1',
#  'CN1CC(C(=O)Nc2cccc(-n3cnnn3)c2)CC1=O',
#  'COc1cccc(-c2ccnc3nc(C4CCC4)nn23)c1',
#  'COCc1nc2nccc(-c3ccc(OC)cc3F)n2n1',
#  'Brc1ccc(-c2ccnc3ncnn23)s1',
#  'O=c1c(=Cc2c[nH]c3ccccc23)sc2nc3ccccc3n12',
#  'COC(=O)C(Cc1ccccc1)NC(=O)CCN1C(=O)c2cccc3cccc(c23)C1=O',
#  'Cc1cccc(C)c1NC(=O)CSc1nnc2sc3ccccc3n12',
#  'CC(=O)Nc1ccc(NC(=O)CSc2nnc3cc(C)c4ccccc4n23)cc1',
#  'CCOC(=O)c1c(-c2ccco2)csc1NC(=O)CSc1nnc2sc3ccccc3n12',
#  'Cc1ccc([N+](=O)[O-])c(OCCSc2ncnc3sc(C)c(C)c23)c1',
#  'Cc1sc2nc(SCC=Cc3ccccc3)nc(N)c2c1C',
#  'Cc1cc(C)nc(NS(=O)(=O)c2ccc(Nc3nc(-c4c(C)nc5ccccn45)cs3)cc2)n1',
#  'COC(=O)c1sc(NC(=O)CSc2nnc3cc(C)c4ccccc4n23)c(C(=O)OC)c1C',
#  'NC(=O)c1c(NC(=O)CSc2ncnc3sc(-c4ccccc4)cc23)sc2c1CCC2',
#  'Cc1sc2ncnc(N3CCN(S(=O)(=O)c4ccc5ccccc5c4)CC3)c2c1C',
#  'O=c1c2ccccc2c(-c2ccccc2)nn1Cc1ccccc1',
#  'COc1cccc(OCCSc2nnc3sc4ccccc4n23)c1',
#  'Cc1ccc(Oc2nc(-c3cccnc3)nc3ccccc23)cc1C',
#  'Cc1sc2ncnc(SCC(=O)Nc3ccc(F)c(Cl)c3)c2c1C',
#  'COC(=O)c1c(NC(=O)CSc2ncnc3sc4c(c23)CCCC4)sc2c1CCC2',
#  'Cc1nc(SCC(=O)Nc2ccc(F)c(Cl)c2)c2c3c(sc2n1)CCCC3',
#  'c1cncc(-c2nc(Oc3cccc4ccccc34)c3ccccc3n2)c1',
#  'O=C1C(=O)N(Cc2cccnc2)C(c2cccnc2)C1C(=O)c1ccc(Cl)cc1',
#  'O=C(CCN1C(=O)c2cccc3cccc(c23)C1=O)N1CCN(Cc2ccc3c(c2)OCO3)CC1',
#  'O=C1c2cccc3cccc(c23)C(=O)N1CCN1CCN(S(=O)(=O)c2cccc3cccnc23)CC1',
#  'O=C(O)c1ccccc1SCCCN1C(=O)c2cccc3cccc(c23)C1=O',
#  'O=C(CN1CCN(CCN2C(=O)c3cccc4cccc(c34)C2=O)CC1)c1ccc(Cl)cc1',
#  'CCOC(=O)CSc1nnc(CSc2nc(N)c3c(C)c(C)sc3n2)n1-c1ccccc1',
#  'Cc1cc(C)n2c(SCC(=O)Nc3c(Cl)cccc3Cl)nnc2n1',
#  'COCCOC(=O)c1c(C)oc2ccc(NS(=O)(=O)c3cc([N+](=O)[O-])ccc3Cl)cc12',
#  'CCCc1oc2ccc(NS(=O)(=O)c3ccc4c5c(cccc35)C(=O)N4)cc2c1C(=O)OCC',
#  'Cc1cc2nnc(SCC(=O)Nc3sc4c(c3C#N)CCC4)n2c2ccccc12',
#  'Cc1sc(NC(=O)CSc2nnc3sc4ccccc4n23)c(C#N)c1C',
#  'Cc1cccc(-c2nc3n(n2)C(=O)CC(c2cccc(F)c2)S3)c1',
#  'Cc1cccn2c(=O)c3cc(S(=O)(=O)c4ccccc4)c(=N)n(Cc4cccnc4)c3nc12',
#  'Cc1cc(N2C(=O)C(=O)C(C(=O)c3ccccc3)C2c2cccc(Br)c2)no1',
#  'COc1ccc(OC)c(C2C(C(=O)c3ccc(Br)cc3)C(=O)C(=O)N2c2cc(C)on2)c1',
#  'CC(=O)c1c(C)oc2ccc(NS(=O)(=O)c3cc4c5c(cccc5c3)C(=O)NC4=O)cc12',
#  'Cc1nnc(SCC(=O)Nc2cccc(-c3nc4ccccc4s3)c2)s1',
#  'O=C(CSc1nnc2ccccn12)Nc1cccc(-c2nc3ccccc3s2)c1',
#  'COc1ccc(CCNS(=O)(=O)c2cc(C)ccc2C)cc1OC',
#  'Cc1cccc(N2C(=O)C(=Nc3ccc(S(N)(=O)=O)cc3)C(Cl)C2=O)c1C',
#  'CCc1ccc(N2C(=O)C(=Nc3cccc(C(F)(F)F)c3)C(Cl)C2=O)cc1',
#  'Cc1nnc(SCC(=O)N2CCCc3ccccc32)n1N',
#  'CCCn1c(=O)c(C(=O)Nc2ncccc2C)c(O)c2ccccc21',
#  'Cc1ccc(-n2cnc(Cl)c2Cn2nncc2C(=O)O)cc1',
#  'COc1ccc2nnc(CCC(=O)Nc3ccc4[nH]c(CC(C)C)nc4c3)n2n1',
#  'O=C(CNC(=O)c1cnccn1)NCCn1ccc2ccc(Br)cc21',
#  'O=C(Cn1nnc2ccccc2c1=O)NCCc1nnc2ccccn12',
#  'O=C(NCCc1nnc2ccccn12)c1c[nH]c2ccc(F)cc2c1=O',
#  'O=C(NCCCc1nc2ccccc2[nH]1)c1ccccc1-n1cnnn1',
#  'COc1ccc2cc(NC(=O)c3ccc4nc(C)c(C)nc4c3)cnc2c1',
#  'CC(C)c1n[nH]c(NC(=O)Cn2nc(-c3ccccc3Cl)ccc2=O)n1',
#  'c1ccc(CCc2nc3nccc(-c4ccccn4)n3n2)cc1',
#  'COC(=O)c1nc(NC(=O)C(c2ccccc2)n2cnnn2)sc1C',
#  'COC(=O)c1nc(NC(=O)CCCn2nnc3ccccc3c2=O)sc1CC(C)C',
#  'Fc1ccc(-c2nc3nccc(-c4ccsc4)n3n2)cc1Cl',
#  'Fc1ccc(-c2nc3nccc(-c4ccco4)n3n2)cc1Cl',
#  'Cn1cnc2cc(CCC(=O)Nc3n[nH]c(C4CCCO4)n3)ccc21',
#  'O=C(Cn1cnc2sccc2c1=O)NCCCc1nnc2ccccn12',
#  'COc1ccc2nnc(CCC(=O)NCCc3nc4ccccc4n3C)n2n1',
#  'CCCCn1cnc2cc(NC(=O)C(Cc3ccccc3)n3cnnn3)ccc21',
#  'COc1ccc(-c2ccnc3nc(Cc4cc(F)cc(F)c4)nn23)cc1',
#  'O=C(CCc1[nH]c(=O)n(Cc2cccc(F)c2)c1O)NCCCc1nnc2ccccn12',
#  'Cc1c(C(=O)Cn2nc3c4c(cccc4c2=O)-c2ccccc2-3)c2ccccc2n1C',
#  'Cc1ccc(-n2cnnn2)cc1NC(=O)c1oc2ccc(Cl)cc2c1C',
#  'Cc1ccc(-n2cnnn2)cc1NC(=O)c1oc2ccc(Br)cc2c1C',
#  'NC1=NC(O)C2C3OC4(O)OC(C(O)C2(N1)C4O)C3(O)CO',
#  'C1CCc2nnnn2CC1',
#  'O=C(NN=Cc1ccccc1O)c1ccccc1O',
#  'CC12CC(=O)C3C(CCC4CC(O)CCC43C)C1CC(=N)N2',
#  'CC(C)(C)C1(O)CC2OC(=O)CC23C(=O)OC2OC(=O)C(O)C231']

# %% [markdown]
# # agonist

# %%
data_agonist = {'smiles': [], 'weight': [], 'logp': [], 'rotatable_bonds': [], 'tpsa': [],'rings': [],'AroRings': [], 'h_donors': [], 'h_acceptors': []}

# %%
for smiles in smiles_agonist:
    mol_weight, logp, rotatable_bonds, tpsa,rings,AroRings,h_donors, h_acceptors = calc_mol_properties(smiles)
    data_agonist['smiles'].append(smiles)
    data_agonist['weight'].append(mol_weight)
    data_agonist['logp'].append(logp)
    data_agonist['rotatable_bonds'].append(rotatable_bonds)
    data_agonist['tpsa'].append(tpsa)
    data_agonist['rings'].append(rings)
    data_agonist['AroRings'].append(AroRings)
    data_agonist['h_donors'].append(h_donors)
    data_agonist['h_acceptors'].append(h_acceptors)

# %%
df_agonist = pd.DataFrame(data_agonist)
df_agonist
# Out:
#                                                 smiles   weight     logp  \
# 0       O=S(=O)(c1cccc(-c2cn3cc(Cl)ccc3n2)c1)N1CCCCCC1  389.908  4.21940
# 1        Cc1cccn2cc(-c3cccc(S(=O)(=O)N4CCCCCC4)c3)nc12  369.490  3.87442
# 2       COc1cc(-c2nn3c(-c4ccc(Cl)cc4)nnc3s2)cc(OC)c1OC  402.863  4.19900
# 3                  O=C(O)Cc1c(-c2ccc(Cl)cc2)nc2ccccn12  286.718  3.28180
# 4         Cc1ccc(Cl)cc1-n1ncc2c1ncn1c(-c3ccccc3O)nnc21  376.807  3.79762
# ..                                                 ...      ...      ...
# 604                                     NCCCS(=O)(=O)O  139.176 -0.77700
# 605   O=C(O)CCC(=O)OC1N=C(c2ccccc2Cl)c2cc(Br)ccc2NC1=O  465.687  3.62610
# 606                 CC1N=C(c2ccccc2F)c2cc(Br)ccc2NC1=O  347.187  3.76620
# 607    CC(C)(C)OC(=O)NCc1n[nH]c(=O)o1.NCc1n[nH]c(=O)o1  330.301 -0.79080
# 608  CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(N=[N+]=[N-])ccc1-2  326.316  2.57640
#
#      rotatable_bonds    tpsa  rings  AroRings  h_donors  h_acceptors
# 0                  3   54.68      4         3         0            4
# 1                  3   54.68      4         3         0            4
# 2                  5   70.77      4         4         0            8
# 3                  3   54.60      3         3         1            3
# 4                  2   81.13      5         5         1            7
# ..               ...     ...    ...       ...       ...          ...
# 604                3   80.39      0         0         2            3
# 605                5  105.06      3         2         2            5
# 606                1   41.46      3         2         1            2
# 607                3  182.13      2         2         4            9
# 608                3  113.19      3         2         0            6
#
# [609 rows x 9 columns]

# %%
df_agonist.to_csv('agonist_MolecularProperties.csv')

# %% [markdown]
# # non_agonist

# %%
data_antagonist = {'smiles': [], 'weight': [], 'logp': [], 'rotatable_bonds': [], 'tpsa': [],'rings': [],'AroRings': [], 'h_donors': [], 'h_acceptors': []}

# %%
for smiles in smiles_antagonist:
    mol_weight, logp, rotatable_bonds, tpsa,rings,AroRings,h_donors, h_acceptors = calc_mol_properties(smiles)
    data_antagonist['smiles'].append(smiles)
    data_antagonist['weight'].append(mol_weight)
    data_antagonist['logp'].append(logp)
    data_antagonist['rotatable_bonds'].append(rotatable_bonds)
    data_antagonist['tpsa'].append(tpsa)
    data_antagonist['rings'].append(rings)
    data_antagonist['AroRings'].append(AroRings)
    data_antagonist['h_donors'].append(h_donors)
    data_antagonist['h_acceptors'].append(h_acceptors)

# %%
df_antagonist = pd.DataFrame(data_antagonist)
df_antagonist
# Out:
#                                                smiles   weight     logp  \
# 0    Br.O=c1[nH]oc(C2CCNCC2)c1-c1cccc([N+](=O)[O-])c1  370.203  2.58800
# 1        Br.O=c1[nH]oc(C2CCNCC2)c1-c1csc(-c2ccccc2)c1  407.333  4.40830
# 2        Br.CC(C)(C)c1ccc(-c2c(C3CCNCC3)o[nH]c2=O)cc1  381.314  3.97730
# 3               O=c1[nH]oc(C2CCNCC2)c1-c1cccc2ccccc12  294.354  3.25510
# 4                                   NC(=O)C1=CCC(N)C1  126.159 -0.48080
# ..                                                ...      ...      ...
# 637       NC1=NC(O)C2C3OC4(O)OC(C(O)C2(N1)C4O)C3(O)CO  319.270 -5.51980
# 638                                    C1CCc2nnnn2CC1  138.174  0.39950
# 639                       O=C(NN=Cc1ccccc1O)c1ccccc1O  256.261  1.86170
# 640          CC12CC(=O)C3C(CCC4CC(O)CCC43C)C1CC(=N)N2  304.434  2.49817
# 641  CC(C)(C)C1(O)CC2OC(=O)CC23C(=O)OC2OC(=O)C(O)C231  326.301 -0.74380
#
#      rotatable_bonds    tpsa  rings  AroRings  h_donors  h_acceptors
# 0                  3  101.17      3         2         2            5
# 1                  3   58.03      4         3         2            4
# 2                  2   58.03      3         2         2            3
# 3                  2   58.03      4         3         2            3
# 4                  1   69.11      1         0         2            2
# ..               ...     ...    ...       ...       ...          ...
# 637                1  190.25      5         0         8           11
# 638                0   43.60      2         1         0            4
# 639                3   81.92      2         2         3            4
# 640                0   73.18      4         0         3            3
# 641                0  119.36      4         0         2            8
#
# [642 rows x 9 columns]

# %%
df_antagonist.to_csv('antagonist_MolecularProperties.csv')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
        'Alcohols_ET': [3079, 5585, 3907, 1732, 1930, 2863, 1239],
        'Alcohols_PT': [6600, 5434, 6838, 8053, 3255, 7236, 7766],
        'Aldehydes_ET': [4419, 7387, 8542, 11728, 7567, 6092, 14615],
        'Aldehydes_PT': [18250, 12514, 26423, 15744, 10321, 15851, 18438],
        'Acids_ET': [396,192 ,274 ,634 ,3679 ,1509 ,1611 ],
        'Acids_PT': [1039 ,630 ,1463 ,1496 ,753 ,1730 ,1813 ],
        'Esters_ET': [0 ,535 ,452 ,606 ,1142 ,261 ,2048 ],
        'Esters_PT': [370 ,279 ,895 ,495 ,106 ,768 ,530 ],
        'Ketones_ET': [477 ,1325 ,628 ,1052 ,1119 ,1086 ,818 ],
        'Ketones_PT': [2356 ,1672 ,2052 ,2572 ,2157 ,2880 ,2658 ],
        'Phenols_ET': [56 ,36 ,0 ,48 ,25 ,42 ,36 ],
        'Phenols_PT': [430 ,190 ,167 ,255 ,103 ,123 ,320 ],
        'Hydrocarbons_ET': [95 ,66 ,0 ,553 ,585 ,267 ,1979 ],
        'Hydrocarbons_PT': [5071,2801,562,1836,2100,2921,1356],
        'Heterocyclic rings_ET':[55,31,248,227,0,1352,849],
        'Heterocyclic rings_PT':[443,252,63,1405,154,521,502]
       }
index = ['FL', 'ES', 'TB', 'MO', 'GK', 'KP', 'KL']

df = pd.DataFrame(data=data,index=index)

# %%
fig1 = plt.figure(figsize=(16,5))
sns.heatmap(df,cmap='YlGnBu',annot = True,fmt='d')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tick_params(axis='both', which='both', length=0)
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), ha='right')
plt.show()

# %%
fig1.savefig('heatmap1.png', dpi=300,bbox_inches = 'tight')
